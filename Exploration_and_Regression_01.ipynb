# %% [markdown]
# ![banner](./images/banner.png "banner")

# %% [markdown]
# # Modelo de aprendizaje automático para la predicción del Ratio Internacional Normalizado (INR) en pacientes bajo terapia con Antagonistas de la Vitamina K

# %% [markdown]
# ## Tabla de contenidos

# %% [markdown]
# - [1. Descripción del proyecto](#1-descripción-del-proyecto)
#   - [1.1 Objetivos](#11-objetivos)
#   - [1.2 Datos](#12-datos)
#   - [1.3 Software](#13-software)
#
# - [2. Exploración y visualización de datos](#2-exploracion-y-visualizacion-de-datos)
#   - [2.1 Carga de datos](#21-carga-de-datos)
#   - [2.2 Generación del csv](#22-generacion-del-csv)
#     - [2.2.1 Simplificación de las variables y pivotación](#221-simplificacion-de-las-variables-y-pivotacion)
#   - [2.3 Limpieza de datos](#23-limpieza-de-datos)
#       - [2.3.1 Valores faltantes y types](#221-simplificacion-de-las-variables-y-pivotacion)
#       - [2.3.2 Duplicados](#221-simplificacion-de-las-variables-y-pivotacion)
#       - [2.3.3 Eliminación de variables redundantes o irrelevantes](#221-simplificacion-de-las-variables-y-pivotacion)
#       - [2.3.4 Rangos y estadistica basica](#221-simplificacion-de-las-variables-y-pivotacion)
#       - [2.3.4 Valores únicos](#221-simplificacion-de-las-variables-y-pivotacion)
#   - [2.4 Feature Importance y análisis de la variable target](#24-feature-importance-y-analisis-de-la-variable-target)
#     - [2.4.1 Oversampling data](#241-oversampling-data)

# %% [markdown]
# ## 1. Descripción del proyecto

# %% [markdown]
# Este proyecto aborda un problema de **predicción de un valor continuo**. Se trata de una tarea supervisada: el modelo aprende a partir de un conjunto amplio de ejemplos donde todas las columnas, incluida la variable target, están completas. Una vez entrenado, aplicamos el modelo a nuevas filas en las que falta precisamente ese valor que queremos estimar. Las columnas con información siempre disponible se denominan características o features.
#
# La variable target puede tomar distintos valores, incluyendo valores inferiores a 1.0 o superiores a 3.0 correspondientes a las mediciones del INR (Ratio Internacional Normalizado). Al ser un valor continuo, la **metodología adecuada es la regresión**.
#
# Si los datos no vinieran etiquetados, si no conociéramos el target desde el inicio, sería necesario recurrir a técnicas de aprendizaje no supervisado, donde el modelo identifica patrones o grupos sin una referencia previa.
#
# En nuestro caso, ajustaremos diferentes modelos de regresión sobre datos de pacientes en tratamiento anticoagulante y elegiremos el que ofrezca el mejor rendimiento. Para evaluar de forma fiable el comportamiento del modelo, dividimos el conjunto de datos en tres partes:
#
# - Conjunto de entrenamiento: contiene los datos completos, incluidos los valores reales del target. Sirven para que el modelo aprenda las relaciones entre las características y la variable objetivo.
#
# - Conjunto de validación: simulamos datos “nuevos” separando previamente el target y ocultándolo al modelo. Tras el entrenamiento, comparamos sus predicciones con los valores reales reservados. Como este conjunto se usa repetidamente para ajustar parámetros, existe el riesgo de que el modelo se adapte demasiado a él y pierda capacidad de generalización (sobreajuste o overfitting).
#
# - Conjunto de prueba: incluye ejemplos completamente nuevos para el modelo entrenado y validado. Es la comprobación final del rendimiento y nos permite estimar cómo respondería ante datos reales que aún no hemos observado.
#
#
# #### Este proyecto contendrá:
#
# - La preparación y limpieza de los datos para que puedan ser utilizados por los modelos de predicción. `Exploration_and_Classification.ipynb`
#
# - La selección de la métrica de rendimiento más adecuada para evaluar la calidad de las predicciones del modelo. `Exploration_and_Classification.ipynb`
#
# - El entrenamiento de los modelos de regresión, ajustando sus parámetros para optimizar la métrica seleccionada. `ModelTraining_and_Conclusions.ipynb`
#
# - La aplicación de los modelos a nuevos datos para generar predicciones de la variable objetivo. `ModelTraining_and_Conclusions.ipynb`
#
# - La evaluación del rendimiento final del modelo comparando sus predicciones con los valores reales de la variable objetivo. `ModelTraining_and_Conclusions.ipynb`
#
# - Un análisis de explicabilidad para comprender cómo el modelo toma sus decisiones y cuáles características influyen más en las predicciones. `XAI.ipynb`
#
# - La cuantificación de la incertidumbre asociada a las predicciones, para entender la confianza que podemos tener en los resultados del modelo. `UQ.ipynb`

# %% [markdown]
# ### 1.1 Objetivos

# %% [markdown]
# El objetivo de este proyecto es **predecir el valor del INR de pacientes bajo tratamiento con anticoagulantes** utilizando variables analíticas, hábitos de vida y otros factores de riesgo relevantes. Este análisis permite identificar patrones que influyen en el INR, facilitando la detección temprana de posibles complicaciones y apoyando la prevención de diagnósticos complejos.

# %% [markdown]
# ### 1.2 Datos

# %% [markdown]
# El conjunto de datos utilizado para entrenar y evaluar nuestro modelo proviene de una **fuente externa fiable de pacientes reales en España (Cataluña)**. Esta información es crucial para el desarrollo de un modelo con **relevancia clínica y aplicabilidad directa** en nuestro entorno sanitario.
#
# Estos registros incluyen una variedad de información clínica, abarcando **datos clínicos básicos**, **resultados de pruebas de hematología y de seguimiento**, además de las **medidas de INR (International Normalized Ratio)** que son fundamentales para el seguimiento de la terapia anticoagulante. Todos los datos han sido **rigurosamente anonimizados** para garantizar la protección de la privacidad de los pacientes y **cumplir estrictamente con las regulaciones de protección de datos vigentes**. Gracias a esta base de datos real, podemos desarrollar y validar modelos en un contexto clínico auténtico y específico, asegurando la calidad y utilidad predictiva para la toma de decisiones médicas.

# %% [markdown]
# Los datos obtenidos se dividen en distintas pestañas de un unico archivo excel.
#
#
# #### Variables
# | | Column Name | Data Type | Description |
# |-|-------------|-----------|-----------|
# | | CODI_PACIENT | Cadena de caracteres (`ID0000`) | Identificador del paciente |
# | | DATA | Fecha formato (`MM-yyyy`) | Fecha mensual del registro de los datos |
# | | DESCRIPCIO VARIABLE | Cadena | Descripción de la medición |
# | | VALOR | Número | Valor de la medición |
# | | DESCRIPCIO VALOR | String | Descripción del valor medido |
#
#
# #### Patologia
# | | Column Name | Data Type | Description |
# |-|-------------|-----------|-----------|
# | | CODI_PACIENT | Cadena de caracteres (`ID0000`) | Identificador del paciente |
# | | DIAGNÒSTIC ASSOCIAT | Cadena | Descripción de la patología del paciente |
#
#
# #### Proves Lab
# | | Column Name | Data Type | Description |
# |-|-------------|-----------|-----------|
# | | CODI_PACIENT | Cadena de caracteres (`ID0000`) | Identificador del paciente |
# | | DATA | Fecha formato (`MM-yyyy`) | Fecha mensual del registro de los datos |
# | | DESCRIPCIO PROVA | Cadena | Descripción de la medición |
# | | VALOR | Número | Valor de la medición |
# | | UNITATS_LAB| String | Tipo de unidad del valor medido |
#
#
# #### Param Coag
# | | Column Name | Data Type | Description |
# |-|-------------|-----------|-----------|
# | | CODI_PACIENT | Cadena de caracteres (`ID0000`) | Identificador del paciente |
# | | DATA | Fecha formato (`MM-yyyy`) | Fecha mensual del registro del control |
# | | DESCRIPCIO VARIABLE | Cadena (`INR`) | Descripción de la medición |
# | | VALOR | Número | Valor de la medición del INR |
#
#
# #### Hematologia
# | | Column Name | Data Type | Description |
# |-|-------------|-----------|-----------|
# | | CODI_PACIENT | Cadena de caracteres (`ID0000`) | Identificador del paciente |
# | | DATA | Fecha formato (`MM-yyyy`) | Fecha mensual del registro del control |
# | | DESCRIPCIO PROVA | Cadena | Descripción de la medición |
# | | VALOR | Número | Valor de la medición del INR |
# | | UNITATS_LAB| String | Tipo de unidad del valor medido |

# %% [markdown]
# La variable **target** que utilizaremos en este análisis se encuentra dentro de la pestaña *Param Coag* y corresponde al valor INR de los pacientes bajo tratamiento con anticoagulantes. Esta variable es continua y representa el riesgo de que un paciente desarrolle complicaciones cardíacas, interpretándose de la siguiente manera:
#
# - **INR < 2.0:** el paciente presenta riesgo de padecer una cardiopatía.
#
# - **INR entre 2.0 y 3.0:** el paciente se encuentra dentro del rango terapéutico, por lo que no presenta riesgo significativo de cardiopatía.
#
# - **INR > 3.0:** aunque el INR es elevado, el paciente no se considera en riesgo de cardiopatía para los efectos de este análisis, aunque sí puede indicar riesgo de hemorragias u otras complicaciones.
#
# Esta definición nos permite utilizar el INR como variable objetivo para entrenar modelos de predicción que puedan estimar el riesgo clínico basado en los datos del paciente.

# %% [markdown]
# ## 1.3 Software
#
# Importamos las siguientes librerías:

# %%
import pandas as pd
import numpy as np

#utils files
from utils.cleaner_standardize_merge import *
from utils.cleaner_shorten_pathologies import *
from utils.personalize_charts import *

# data exploration and preparation  
from sklearn.feature_selection import mutual_info_classif
from functools import reduce

# plotting and displaying in the notebook
import seaborn as sns
from matplotlib import pyplot as plt
from IPython.display import display
from sklearn import tree
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import math
from scipy import stats

#SMOTE
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import LabelEncoder

#model evaluation
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression


import re
import unicodedata

# %% [markdown]
# # 2. Exploración y visualización de datos
#
# ## 2.1 Carga de datos
#
# Vamos a cargar los datos del fichero `Estudi_Anticoagulants.csv`, empezaremos por la ventana de variables:

# %%
df_variables =  pd.read_excel("data/Estudi_Anticoagulants.xlsx", sheet_name="VARIABLES")
df_variables.head()
#df_variables.info()
# Out:
#   CODI_PACIENT     DATA            DESCRIPCIO VARIABLE  VALOR  \
# 0       ID0002  01/2024               Potasi (K) Sèric  58.00
# 1       ID0003  01/2024                      Ara fuma?   0.00
# 2       ID0003  01/2024      Tipus d'intervenció tabac   1.00
# 3       ID0003  01/2024  IMC - Índex de Massa Corporal  24.01
# 4       ID0003  01/2024    Pressió Arterial Diastòlica  55.00
#
#      DESCRIPCIO VALOR
# 0                 NaN
# 1                  No
# 2  Reforç de conducta
# 3                 NaN
# 4                 NaN

# %% [markdown]
# El conjunto de datos contiene información de **118.014 pacientes y 5 columnas** que describen sus características básicas a nivel médico, incluyendo aspectos bioquímicos, indicadores de hábitos de salud, medidas corporales y signos vitales.

# %% [markdown]
# Vamos a cargar los datos de la siguiente ventana `PROVES LAB`

# %%
df_labTest = pd.read_excel("data/Estudi_Anticoagulants.xlsx", sheet_name="PROVES LAB")
df_labTest.head()
#df_labTest.info()
# Out:
#   CODI_PACIENT     DATA                             DESCRIPCIO PROVA  VALOR  \
# 0       ID0003  01/2024    ALANINA AMINOTRANSFERASA (GPT/ALT), SUERO  10,80
# 1       ID0003  01/2024                          Microalbuminuria /L  <3,00
# 2       ID0003  01/2024  ASPARTATO AMINOTRANSFERASA (GOT/AST), SUERO  15,60
# 3       ID0003  01/2024                     BILIRRUBINA TOTAL, SUERO   0,40
# 4       ID0003  01/2024                            CREATININA, SUERO   0,70
#
#   UNITATS_LAB
# 0         U/L
# 1         g/L
# 2         U/L
# 3       mg/dL
# 4       mg/dL

# %% [markdown]
# El conjunto de datos contiene información de **9.924 pacientes y 5 columnas** que reflejan su estado bioquímico y funcional, abarcando marcadores hepáticos, renales y metabólicos. En conjunto, proporciona una visión más especifica del perfil clínico de cada paciente.

# %% [markdown]
# Vamos a cargar los datos de la siguiente ventana `PARAM COAG`:

# %%
df_INR = pd.read_excel("data/Estudi_Anticoagulants.xlsx", sheet_name="PARAM COAG")
df_INR.head()
#df_INR.info()
# Out:
#   CODI_PACIENT     DATA DESCRPCIO VARIABLE  VALOR
# 0       ID0009  03/2024                INR    4.3
# 1       ID0009  03/2024                INR    7.0
# 2       ID0009  03/2024                INR    4.4
# 3       ID0044  11/2024                INR    2.8
# 4       ID0044  11/2024                INR    1.5

# %% [markdown]
# Este conjunto de datos es considerablemente amplio, con **1969  registros y 5 variables** que describen los controles de INR realizados a los pacientes.
#
# Dentro de este conjunto se identifica nuestra **variable objetivo 'target', que indica si el paciente cuenta con un registro de INR** y el valor correspondiente. Esta variable permite evaluar la presencia y magnitud de dicha medición, siendo la clave de este análisis.

# %% [markdown]
# Vamos a cargar los datos de la siguiente ventana `HEMATOLOGIA`:

# %%
df_hematology = pd.read_excel("data/Estudi_Anticoagulants.xlsx", sheet_name="HEMATOLOGIA")
df_hematology.head()
#df_hematology.info()
# Out:
#   CODI_PACIENT     DATA           DESCRIPCIO PROVA  VALOR UNITATS_LAB
# 0       ID0003  01/2024                Hematocrito  32,20           %
# 1       ID0003  01/2024                Hemoglobina  10,30        g/dL
# 2       ID0003  01/2024                   Hematíes   3,28   10Exp12/L
# 3       ID0003  01/2024  Volumen corpuscular medio  98,20          fL
# 4       ID0003  01/2024  Conc.Hb.Corpuscular Media  32,10        g/dL

# %% [markdown]
# Vamos a cargar los datos de la siguiente ventana `PATOLOGIA`:

# %%
df_patology = pd.read_excel("data/Estudi_Anticoagulants.xlsx", sheet_name="PATOLOGIA")
df_patology.head()
#df_patology.info()
# Out:
#   CODI_PACIENT                         DIAGNÒSTIC ASSOCIAT
# 0       ID8035  CIRROSI HEPÀTICA ALCOHÒLICA, SENSE ASCITES
# 1       ID1745      FIBRIL·LACIÓ AURICULAR NO ESPECIFICADA
# 2       ID6185              FIBRIL·LACIÓ AURICULAR CRÒNICA
# 3      ID12021            FIBRIL·LACIÓ AURICULAR PERMANENT
# 4       ID7015      FIBRIL·LACIÓ AURICULAR NO ESPECIFICADA

# %% [markdown]
# Este conjunto de datos tiene, con **310  registros y 2 variables** que describen las patologias que tiene los pacientes que se presentan al control.

# %% [markdown]
# ## 2.2 Generación del csv

# %% [markdown]
# ### 2.2.1 Agrupación y pivotación

# %% [markdown]
# Disponemos de un registro casi mensual de los datos de cada paciente, pero nuestro objetivo es identificar qué valores influyen más en esta medición. En cada conjunto de datos, agruparemos por el ID del paciente y por la descripción, conservando el valor promedio de cada medida. Posteriormente, realizaremos un pivoteo para transformar las filas en columnas. Todos los datos se encuentran interrelacionados mediante el campo CODI_PACIENT.

# %% [markdown]
# **Variables clínicas iniciales: agrupamos y pivotamos.**

# %%
df_variables_gruped = (
    df_variables.groupby(["CODI_PACIENT", "DESCRIPCIO VARIABLE"])
      .mean(numeric_only=True)
      .reset_index()
)

# Limpiar nombres de variables
df_variables_gruped['DESCRIPCIO VARIABLE'] = df_variables_gruped['DESCRIPCIO VARIABLE'].str.strip()

# Convertir valores a string (si hay mezcla de tipos)
df_variables_gruped['VALOR'] = df_variables_gruped['VALOR'].astype(str)

# Pivot seguro
df_variables_gruped_pivot = df_variables_gruped.pivot_table(
    index='CODI_PACIENT',
    columns='DESCRIPCIO VARIABLE',
    values='VALOR',
    aggfunc='first'  # toma el primer valor si hay duplicados
).reset_index()

df_variables_gruped_pivot = df_variables_gruped_pivot.rename_axis(None, axis=1)
df_variables_gruped_pivot.head()
# Out:
#   CODI_PACIENT Activitat exercici en consulta Ara fuma? Cigarretes/dia  \
# 0       ID0002                            NaN       NaN            NaN
# 1       ID0003                            NaN       0.0            NaN
# 2       ID0004                            NaN       0.0            NaN
# 3       ID0005                            NaN       1.0            NaN
# 4       ID0006                            NaN       0.0            NaN
#
#   Colesterol total Consell consum d'alcohol Cribratge abús alcohol (Audit-C)  \
# 0              NaN                      NaN                              NaN
# 1              NaN                      NaN                              NaN
# 2              NaN                      NaN                              1.5
# 3              NaN                      NaN                              NaN
# 4              NaN                      NaN                              NaN
#
#   Cribratge alimentació Etapa canvi. Activitat física Freqüència cardíaca  \
# 0                   NaN                           NaN                 NaN
# 1                   NaN                           NaN   75.66666666666667
# 2                   NaN                           NaN                74.5
# 3                   NaN                           NaN                 NaN
# 4                   NaN                           NaN                90.0
#
#    ... Qüestionari CBPAAT d'activitat física Ritme cardíac  \
# 0  ...                                   NaN           NaN
# 1  ...                                   NaN           1.0
# 2  ...                                   NaN           1.0
# 3  ...                                   NaN           NaN
# 4  ...                                   NaN           1.0
#
#   Sedestació interrompuda Temps assegut (h/d)  \
# 0                     NaN                 NaN
# 1                     NaN                 NaN
# 2                     NaN                 NaN
# 3                     NaN                 NaN
# 4                     NaN                 NaN
#
#   Test dep. nicotina (Fagerström) breu Tipus d'exposició ambiental de tabac  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
#
#   Tipus d'intervenció tabac Tipus de tabac Valoració resultat AUDIT-C  \
# 0                       NaN            NaN                        NaN
# 1                       1.0            NaN                        NaN
# 2                       1.0            NaN                        NaN
# 3                       NaN            NaN                        NaN
# 4                       1.0            NaN                        NaN
#
#   Voldria deixar de fumar?
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# **Pruebas de laboratorio: agrupamos y pivotamos.**

# %%
 #Convertir VALOR a numérico (primero reemplazar comas si las hay)
df_labTest["VALOR"] = (
    df_labTest["VALOR"]
        .astype(str)
        .str.replace(",", ".", regex=False)
)

df_labTest["VALOR"] = pd.to_numeric(df_labTest["VALOR"], errors="coerce")

df_labTest_gruped = (
    df_labTest.groupby(["CODI_PACIENT", "DESCRIPCIO PROVA"])
      .mean(numeric_only=True)
      .round(2)
      .reset_index()
)
df_labTest_gruped_pivot = df_labTest_gruped.pivot_table(
    index='CODI_PACIENT',
    columns='DESCRIPCIO PROVA',
    values='VALOR',
    aggfunc='first'
).reset_index()

df_labTest_gruped_pivot = df_labTest_gruped_pivot.rename_axis(None, axis=1)

df_labTest_gruped_pivot.head()
# Out:
#   CODI_PACIENT    ALT (GPT)    Creatinina    Glucosa    Potassi    Sodi  \
# 0       ID0003          NaN           NaN        NaN        NaN     NaN
# 1       ID0009          NaN           NaN        NaN        NaN     NaN
# 2       ID0044          NaN           NaN        NaN        NaN     NaN
# 3       ID0046          NaN           NaN        NaN        NaN     NaN
# 4       ID0073          NaN           NaN        NaN        NaN     NaN
#
#      Urea  ALANINA AMINOTRANSFERASA (ALT) (GPT)  \
# 0     NaN                                 13.50
# 1     NaN                                   NaN
# 2     NaN                                 40.29
# 3     NaN                                   NaN
# 4     NaN                                   NaN
#
#    ALANINA AMINOTRANSFERASA (GPT/ALT), SUERO  \
# 0                                       11.7
# 1                                        9.6
# 2                                        NaN
# 3                                       19.2
# 4                                       16.2
#
#    ALANINA AMINOTRANSFERASA (SÈRUM); C.CAT.  ...  \
# 0                                       NaN  ...
# 1                                       NaN  ...
# 2                                       NaN  ...
# 3                                       NaN  ...
# 4                                       NaN  ...
#
#    Srml-Lactat-deshidrogenasa; c.cat.  UREA (SÈRUM); C.SUBST  UREA SERUM  \
# 0                                 NaN                    NaN         NaN
# 1                                 NaN                    NaN         NaN
# 2                                 NaN                    NaN         NaN
# 3                                 NaN                    NaN         NaN
# 4                                 NaN                    NaN         NaN
#
#    UREA SÈRUM  UREA Sèrum  UREA, SUERO  Urea sèrum  Urea sèrum (3091-6)   \
# 0       30.49         NaN          NaN         NaN                   NaN
# 1         NaN         NaN          NaN         NaN                   NaN
# 2      173.41         NaN          NaN         NaN                   NaN
# 3       12.18         NaN          NaN         NaN                   NaN
# 4         NaN         NaN          NaN         NaN                   NaN
#
#    Urea-Sèrum  Uri-Albúmina orina recent
# 0         NaN                        NaN
# 1         NaN                        NaN
# 2         NaN                        NaN
# 3         NaN                        NaN
# 4         NaN                        NaN
#
# [5 rows x 232 columns]

# %% [markdown]
# **Controles de INR: agrupamos y pivotamos.**
#
# Los controles de INR se realizan cada dos semanas a los pacientes; por ello, calcularemos la media ponderada por tiempo. De esta manera obtendremos valores más precisos que usando únicamente la media simple.

# %%
 #Convertir VALOR a numérico (primero reemplazar comas si las hay)
df_INR["VALOR"] = (
    df_INR["VALOR"]
        .astype(str)
        .str.replace(",", ".", regex=False)
)

df_INR["VALOR"] = pd.to_numeric(df_INR["VALOR"], errors="coerce")
df_INR['DATA'] = pd.to_datetime(df_INR['DATA'])
df_INR.to_csv('data/df_INR.csv')
# Ordenamos por paciente y fecha
df_INR = df_INR.sort_values(['CODI_PACIENT', 'DESCRPCIO VARIABLE', 'DATA'])

# Calculamos diferencia en meses entre fechas consecutivas por paciente y variable
df_INR['diff_months'] = df_INR.groupby(['CODI_PACIENT', 'DESCRPCIO VARIABLE'])['DATA'].diff().dt.days / 30
df_INR['diff_months'] = df_INR['diff_months'].fillna(1)  # Primer valor pondera 1 mes mínimo

# Media ponderada por tiempo
df_INR_gruped = df_INR.groupby(['CODI_PACIENT', 'DESCRPCIO VARIABLE']).apply(
    lambda x: (x['VALOR'] * x['diff_months']).sum() / x['diff_months'].sum()
).reset_index(name='VALOR')

# Redondeamos a 2 decimales
df_INR_gruped['VALOR'] = df_INR_gruped['VALOR'].round(2)

df_INR_gruped_pivot = df_INR_gruped.pivot_table(
    index='CODI_PACIENT',
    columns='DESCRPCIO VARIABLE',
    values='VALOR',
    aggfunc='first'
).reset_index()

df_INR_gruped_pivot = df_INR_gruped_pivot.rename_axis(None, axis=1)

df_INR_gruped_pivot.head()
df_INR_gruped.to_csv('data/df_INR_gruped.csv')
# Out:
# C:\Users\VALER\AppData\Local\Temp\ipykernel_6776\4145051769.py:9: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_INR['DATA'] = pd.to_datetime(df_INR['DATA'])
# C:\Users\VALER\AppData\Local\Temp\ipykernel_6776\4145051769.py:19: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_INR_gruped = df_INR.groupby(['CODI_PACIENT', 'DESCRPCIO VARIABLE']).apply(

# %% [markdown]
# **Hematologia: agrupamos y pivotamos.**

# %%
 #Convertir VALOR a numérico (primero reemplazar comas si las hay)
df_hematology["VALOR"] = (
    df_hematology["VALOR"]
        .astype(str)
        .str.replace(",", ".", regex=False)
)

df_hematology["VALOR"] = pd.to_numeric(df_hematology["VALOR"], errors="coerce")

df_hematology_gruped = (
    df_hematology.groupby(["CODI_PACIENT", "DESCRIPCIO PROVA"])
      .mean(numeric_only=True)
      .round(2)
      .reset_index()
)
df_hematology_gruped_pivot = df_hematology_gruped.pivot_table(
    index='CODI_PACIENT',
    columns='DESCRIPCIO PROVA',
    values='VALOR',
    aggfunc='first'
).reset_index()

df_hematology_gruped_pivot = df_hematology_gruped_pivot.rename_axis(None, axis=1)

df_hematology_gruped_pivot.head()
# Out:
#   CODI_PACIENT      Basòfils      Eosinòfils      Limfòcits      Monòcits  \
# 0       ID0003           NaN             NaN            NaN           NaN
# 1       ID0009           NaN             NaN            NaN           NaN
# 2       ID0044           NaN             NaN            NaN           NaN
# 3       ID0046           NaN             NaN            NaN           NaN
# 4       ID0073           NaN             NaN            NaN           NaN
#
#        Neutròfils segmentats    Amplitud distribució eritrocitària (ADE)  \
# 0                        NaN                                         NaN
# 1                        NaN                                         NaN
# 2                        NaN                                         NaN
# 3                        NaN                                         NaN
# 4                        NaN                                         NaN
#
#      Conc. hemoglobina corpuscular mitjana (CHCM)    Hematíes    Hematòcrit  \
# 0                                             NaN         NaN           NaN
# 1                                             NaN         NaN           NaN
# 2                                             NaN         NaN           NaN
# 3                                             NaN         NaN           NaN
# 4                                             NaN         NaN           NaN
#
#    ...     VCM  VCM (787-2)   VOLUM CORPUSCULAR MIG  VOLUM PLAQUETAR MIG  VPM  \
# 0  ...   95.48           NaN                    NaN                  NaN  NaN
# 1  ...     NaN           NaN                    NaN                  NaN  NaN
# 2  ...  103.26           NaN                    NaN                  NaN  NaN
# 3  ...   86.40           NaN                    NaN                  NaN  NaN
# 4  ...     NaN           NaN                    NaN                  NaN  NaN
#
#    Volum corpuscular mig (VCM)  Volum corpuscular mitjà-Sang  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                        93.77                           NaN
# 4                          NaN                           NaN
#
#    Volum plaquetari mig  Volum plaquetari mitjà-Sang  \
# 0                   NaN                          NaN
# 1                   NaN                          NaN
# 2                   NaN                          NaN
# 3                   9.9                          NaN
# 4                   NaN                          NaN
#
#    Volumen corpuscular medio
# 0                      95.42
# 1                      95.70
# 2                        NaN
# 3                      91.50
# 4                      80.60
#
# [5 rows x 212 columns]

# %% [markdown]
# **Patologias: simplemente agrupamos**

# %%
df_patology_gruped = (
    df_patology.groupby(["CODI_PACIENT", "DIAGNÒSTIC ASSOCIAT"])
      .mean(numeric_only=True)
      .round(2)
      .reset_index()
)

# %%
df_patology_gruped['DIAGNÒSTIC ASSOCIAT'].unique()
# Out:
# array(['FLEBITIS I TROMBOFLEBITIS VASOS PROFUNDS NE EXTREM. INF. NE',
#        'FIBRIL·LACIÓ AURICULAR NO ESPECIFICADA',
#        'ALETEIG [FLUTTER] AURICULAR NO ESPECIFICAT',
#        'TRASTORN NO REUMÀTIC DE LA VÀLVULA AÒRTICA NO ESPECIFICAT',
#        "ALTRES TIPUS D'EMBÒLIA PULMONAR SENSE COR PULMONAR AGUT",
#        'FIBRIL·LACIÓ AURICULAR PERMANENT',
#        'FIBRIL·LACIÓ AURICULAR CRÒNICA',
#        'ARRÍTMIA CARDÍACA NO ESPECIFICADA',
#        "ÚS D'ANTICOAGULANTS A LLARG TERMINI (ACTUAL)",
#        'EMBÒLIA I TROMBOSI DE VENA NO ESPECIFICADA, AGUDES',
#        "ALT. TRAST. D'ARTÈRIES ARTERIOLES I CAPIL·LARS EN MAL. CAL",
#        'MIOCARDIOPATIA DILATADA', 'INFART CEREBRAL NO ESPECIFICAT',
#        'ALTRES TIPUS DE DESPOLARITZACIÓ PREMATURA',
#        'ESTENOSI AÒRTICA NO REUMÀTICA (VÀLVULA)',
#        "TRAST. D'ADAPTACIÓ MIXT D'ANSIETAT I ESTAT D'ÀNIM DEPRIMIT",
#        "ATEROSCLEROSI D'ARTÈRIES NADIUES NE, EXTREMITAT NE",
#        'ATAC ISQUÈMIC CEREBRAL TRANSITORI NO ESPECIFICAT',
#        'TRASTORN NO REUMÀTIC DE LA VÀLVULA MITRAL NO ESPECIFICAT',
#        'SÍNCOPE I COL·LAPSE',
#        'HEMORRÀGIA SUBDURAL NO TRAUMÀTICA NO ESPECIFICADA',
#        'PALPITACIONS', 'TAQUICÀRDIA PAROXISMAL NO ESPECIFICADA',
#        'CARDIOPATIA ISQUÈMICA CRÒNICA NO ESPECIFICADA',
#        'VALVULOPATIA MITRAL REUMÀTICA NO ESPECIFICADA',
#        'IMEST DE LOCALITZACIÓ NO ESPECIFICADA',
#        'PRESÈNCIA DE VÀLVULA CARDÍACA PROTÈTICA',
#        'INSUFICIÈNCIA MITRAL NO REUMÀTICA (VÀLVULA)',
#        'FIBRIL·LACIÓ AURICULAR PAROXISMAL',
#        'ANGINA DE PIT NO ESPECIFICADA',
#        'VASCULOPATIA NECROSANT NO ESPECIFICADA',
#        'LUPUS ERITEMATÓS SISTÈMIC NO ESPECIFICAT',
#        'BONY EN MAMA NO ESPECIFICAT, MAMA NO ESPECIFICADA',
#        'INSUFICIÈNCIA AÒRTICA NO REUMÀTICA (VÀLVULA)',
#        "TRASTORN VASCULAR NO ESPECIFICAT D'INTESTÍ",
#        'ENDOCARDITIS I TRASTORNS VÀLVULA CARDÍACA EN MAL. CAL',
#        "ALTRES TIPUS D'HEMOGLOBINOPATIA",
#        'ANGIOPATIA PERIFÈRICA NO ESPECIFICADA',
#        'INSUFICIÈNCIA CARDÍACA NO ESPECIFICADA',
#        'INSUFICIÈNCIA MITRAL REUMÀTICA',
#        'CIRROSI HEPÀTICA ALCOHÒLICA, SENSE ASCITES',
#        'SÍNDROME POSTTROMBÒTICA SENSE COMPLICACIONS, EXTREMITAT NE',
#        'FIBRIL·LACIÓ AURICULAR CRÒNICA NE',
#        'FLEBITIS I TROMBOFLEBITIS DE LOCALITZACIÓ NO ESPECIFICADA'],
#       dtype=object)

# %% [markdown]
# Los valores de las patologías no son uniformes ni concisos en el dataset. Por ello, utilizaremos la utilidad shorten_diagnoses para acortar y estandarizar los nombres de las variables.

# %%
df_patology_gruped = shorten_diagnoses(df_patology_gruped, column='DIAGNÒSTIC ASSOCIAT', inplace=False)

df_patology_gruped['DIAGNÒSTIC ASSOCIAT'].unique()
# Out:
# Shortened 0/300 variable names (0.0%)
# array(['Flebitis_Profunda', 'FA_NE', 'Flutter_NE', 'Valv_Aort_NReum_NE',
#        'EP_Other_No_CorPulm', 'FA_Perm', 'FA_Cron', 'Arritmia_NE',
#        'Anticoagulant_LT', 'Trombosi_Venosa_Aguda', 'Alt_Art_Arter_Cap',
#        'Miocardiopatia_Dilatada', 'Infart_Cerebral_NE',
#        'Despol_Prem_Other', 'Estenosi_Aort_NReum', 'Trast_Adapt_Mixt',
#        'Aterosclerosis_NE', 'AIT_NE', 'Valv_Mitral_NReum_NE', 'Sincop',
#        'HSD_NE', 'Palpitacions', 'Taquicardia_Parox_NE', 'CI_Cron_NE',
#        'Valv_Mitral_Reum_NE', 'IMEST_NE', 'Valvula_Protetica',
#        'Insuf_Mitral_NReum', 'FA_Parox', 'Angina_NE',
#        'Vasculopatia_Nec_NE', 'LES_NE', 'Bony_Mama_NE',
#        'Insuf_Aort_NReum', 'Trast_Vascular_Intesti_NE',
#        'Endocarditis_Cal', 'Hemoglobinopatia_Other',
#        'Angiopatia_Periferica_NE', 'IC_NE', 'Insuf_Mitral_Reum',
#        'Cirrosi_Alcoholica_NoAsc', 'SPT_NoComp_NE', 'FA_Cron_NE',
#        'Flebitis_NE'], dtype=object)

# %% [markdown]
# Unimos todos los datasets mediante el identificador del paciente, con el objetivo de trabajar sobre un único conjunto de datos

# %%
# List of all DataFrames to merge
dfs = [df_INR_gruped_pivot, df_labTest_gruped_pivot, df_variables_gruped_pivot, df_hematology_gruped_pivot, df_patology_gruped]

# Merge all DataFrames on 'CODI_PACIENT' using left join
df_investig_INR = reduce(lambda left, right: left.merge(right, on='CODI_PACIENT', how='left'), dfs)

df_investig_INR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Columns: 472 entries, CODI_PACIENT to DIAGNÒSTIC ASSOCIAT
# dtypes: float64(443), object(29)
# memory usage: 490.6+ KB

# %% [markdown]
# Como podemos observar, algunas variables representan lo mismo o están descritas de formas diferentes. Por ello, utilizaremos la utilidad process_lab_data, que recorrerá los valores, registrará cambios cuando se trate de pacientes distintos y, además, renombrará las columnas con nombres más concisos y descriptivos.

# %%
df_investig_INR = process_lab_data(df_investig_INR)
df_investig_INR.info()
# Out:
# Iniciant el processament de les dades...
# CODI_PACIENT
# CODI_PACIENT
# Son iguales
# INR
# INR
# Son iguales
#   ALT (GPT)
# __ALT_(GPT)
# Son iguales
#   Creatinina
# __CREATININA
# Son iguales
#   Glucosa
# __GLUCOSA
# Son iguales
#   Potassi
# __POTASSI
# Son iguales
#   Sodi
# __SODI
# Son iguales
#   Urea
# __UREA
# Son iguales
# ALANINA AMINOTRANSFERASA (ALT) (GPT)
# ALANINA_AMINOTRANSFERASA_(ALT)_(GPT)
# Son iguales
# ALANINA AMINOTRANSFERASA (GPT/ALT), SUERO
# ALANINA_AMINOTRANSFERASA_(GPT/ALT)_SUERO
# Son iguales
# ALANINA AMINOTRANSFERASA (SÈRUM); C.CAT.
# ALANINA_AMINOTRANSFERASA__
# Son iguales
# ALBÚMINA  (MAU) ORINA
# ALBÚMINA__(MAU)_ORINA
# Son iguales
# ALBÚMINA Orina esporádica
# ALBÚMINA_ORINA_ESPORÁDICA
# Son iguales
# ALT (GPT) Sèrum
# ALT_(GPT)_SÈRUM
# Son iguales
# ASPARTAT AMINOTRANSFERASA (SÈRUM); C.CAT
# ASPARTAT_AMINOTRANSFERASA_
# Son iguales
# ASPARTATO AMINOTRANSFERASA (AST) (GOT)
# ASPARTATO_AMINOTRANSFERASA_(AST)_(GOT)
# Son iguales
# ASPARTATO AMINOTRANSFERASA (GOT/AST), SUERO
# ASPARTATO_AMINOTRANSFERASA_(GOT/AST)_SUERO
# Son iguales
# AST (GOT) Sèrum
# AST_(GOT)_SÈRUM
# Son iguales
# AST (GOT), suero
# AST_(GOT)_SUERO
# Son iguales
# Alanina aminotranferasa (ALAT), suero
# ALANINA_AMINOTRANFERASA_(ALAT)_SUERO
# Son iguales
# Alanina aminotransferasa (ALT) sèrum
# ALANINA_AMINOTRANSFERASA_(ALT)_SÈRUM
# Son iguales
# Alanina aminotransferasa (ALT) sèrum (1742-6)
# ALANINA_AMINOTRANSFERASA_(ALT)_SÈRUM_(1742_6)_
# Son iguales
# Alanina aminotransferasa-Sèrum
# ALANINA_AMINOTRANSFERASA_SÈRUM
# Son iguales
# Aspartat aminotranferasa (AST) sèrum
# ASPARTAT_AMINOTRANFERASA_(AST)_SÈRUM
# Son iguales
# Aspartat aminotranferasa (AST) sèrum (1920-8)
# ASPARTAT_AMINOTRANFERASA_(AST)_SÈRUM_(1920_8)_
# Son iguales
# Aspartat aminotransferasa-Sèrum
# ASPARTAT_AMINOTRANSFERASA_SÈRUM
# Son iguales
# BILIRRUBINA TOTAL, SUERO
# BILIRRUBINA_TOTAL_SUERO
# Son iguales
# BILIRUBINA (SÈRUM); C.SUBST.
# BILIRUBINA_(SÈRUM)_C_SUBST_
# Son iguales
# BILIRUBINA TOTAL
# BILIRUBINA_TOTAL
# Son iguales
# BILIRUBINA TOTAL Sèrum
# BILIRUBINA_TOTAL_SÈRUM
# Son iguales
# Bilirrubina total, suero
# BILIRRUBINA_TOTAL_SUERO
# Son iguales
# Bilirubina total sèrum
# BILIRUBINA_TOTAL_SÈRUM
# Son iguales
# Bilirubina total sèrum (1975-2)
# BILIRUBINA_TOTAL_SÈRUM_(1975_2)_
# Son iguales
# Bilirubina total-Sèrum
# BILIRUBINA_TOTAL_SÈRUM
# Son iguales
# CALCI (SÈRUM); C.SUBST.
# CALCI_(SÈRUM)_C_SUBST_
# Son iguales
# CALCI SÈRUM
# CALCI_SÈRUM
# Son iguales
# CALCI Sèrum
# CALCI_SÈRUM
# Son iguales
# CALCIO, SUERO
# CALCIO_SUERO
# Son iguales
# CLOR Sèrum
# CLOR_SÈRUM
# Son iguales
# CLORUR (SÈRUM); C.SUBST. «PART DE CONJUNT»
# CLORUR_(SÈRUM)_C_SUBST__«PART_DE_CONJUNT»
# Son iguales
# CLORUR SÈRUM
# CLORUR_SÈRUM
# Son iguales
# CLORURO, SUERO
# CLORURO_SUERO
# Son iguales
# CREATINA CINASA (CK)
# CREATINA_CINASA_(CK)
# Son iguales
# CREATINA KINASA (CK) Sèrum
# CREATINA_KINASA_(CK)_SÈRUM
# Son iguales
# CREATINA-CINASA (CK), SUERO
# CREATINA_CINASA_(CK)_SUERO
# Son iguales
# CREATININA SERUM
# CREATININA_SERUM
# Son iguales
# CREATININA SÈRUM
# CREATININA_SÈRUM
# Son iguales
# CREATININA Sèrum
# CREATININA_SÈRUM
# Son iguales
# CREATININA, SUERO
# CREATININA_SUERO
# Son iguales
# CREATININI (SÈRUM); C.SUBST
# CREATININI_(SÈRUM)_C_SUBST
# Son iguales
# Calci  sèrum
# CALCI__SÈRUM
# Son iguales
# Calci  sèrum (17861-6)
# CALCI__SÈRUM_(17861_6)_
# Son iguales
# Calci sèrum
# CALCI_SÈRUM
# Son iguales
# Calcio, suero
# CALCIO_SUERO
# Son iguales
# Clor
# CLOR
# Son iguales
# Clor (2075-0)
# CLOR_(2075_0)_
# Son iguales
# Clorur-Sèrum
# CLORUR_SÈRUM
# Son iguales
# Creatina cinasa (CK) sèrum
# CREATINA_CINASA_(CK)_SÈRUM
# Son iguales
# Creatina cinasa (CK) sèrum (2157-6)
# CREATINA_CINASA_(CK)_SÈRUM_(2157_6)_
# Son iguales
# Creatinina sèrum
# CREATININA_SÈRUM
# Son iguales
# Creatinina sèrum (2160-0)
# CREATININA_SÈRUM_(2160_0)_
# Son iguales
# Creatinina, suero
# CREATININA_SUERO
# Son iguales
# Creatinini-Sèrum
# CREATININI_SÈRUM
# Son iguales
# F. G. ESTIMAT (CKD-EPI) Sèrum
# F__G__ESTIMAT_(CKD_EPI)_SÈRUM
# Son iguales
# FERRITINA
# FERRITINA
# Son iguales
# FERRITINA (SÈRUM); C.MASSA
# FERRITINA_(SÈRUM)_C_MASSA
# Son iguales
# FERRITINA Sèrum
# FERRITINA_SÈRUM
# Son iguales
# FERRITINA, SUERO
# FERRITINA_SUERO
# Son iguales
# FERRO Sèrum
# FERRO_SÈRUM
# Son iguales
# FILTRAT GLOMERULAR (ESTIMACIÓ SEGONS CKD-EPI) (SÈRUM)
# FILTRAT_GLOMERULAR_(ESTIMACIÓ_SEGONS_CKD_EPI)_(SÈRUM)
# Son iguales
# FOSFATASA ALCALINA
# FOSFATASA_ALCALINA
# Son iguales
# FOSFATASA ALCALINA (ALP, AP), SUERO
# FOSFATASA_ALCALINA_(ALP_AP)_SUERO
# Son iguales
# FOSFATASA ALCALINA (SÈRUM); C.CAT.
# FOSFATASA_ALCALINA__
# Son iguales
# FOSFATASA ALCALINA Sèrum
# FOSFATASA_ALCALINA_SÈRUM
# Son iguales
# Ferritina-Sèrum
# FERRITINA_SÈRUM
# Son iguales
# Ferro (II+III)-Sèrum
# FERRO_(II+III)_SÈRUM
# Son iguales
# Filtrado Glomerular (Ecuación: CKD-EPI)
# FILTRADO_GLOMERULAR_(ECUACIÓN:_CKD_EPI)
# Son iguales
# Filtrado glomerular
# FILTRADO_GLOMERULAR
# Son iguales
# Filtrat glomerular estimat
# FILTRAT_GLOMERULAR_ESTIMAT
# Son iguales
# Filtrat glomerular estimat (62238-1)
# FILTRAT_GLOMERULAR_ESTIMAT_(62238_1)_
# Son iguales
# Filtrat glomerular estimat sèrum
# FILTRAT_GLOMERULAR_ESTIMAT_SÈRUM
# Son iguales
# Fosfatasa alcalina sèrum
# FOSFATASA_ALCALINA_SÈRUM
# Son iguales
# Fosfatasa alcalina sèrum (6768-6)
# FOSFATASA_ALCALINA_SÈRUM_(6768_6)_
# Son iguales
# Fosfatasa alcalina, suero
# FOSFATASA_ALCALINA_SUERO
# Son iguales
# GLICOHEMOGLOBINA (A1C) (SANG); FR.MASSA
# GLICOHEMOGLOBINA_(A1C)_(SANG)_FR_MASSA
# Son iguales
# GLUCEMIA BASAL
# GLUCEMIA_BASAL
# Son iguales
# GLUCOSA (SÈRUM); C.SUBST.
# GLUCOSA_(SÈRUM)_C_SUBST_
# Son iguales
# GLUCOSA SÈRUM
# GLUCOSA_SÈRUM
# Son iguales
# GLUCOSA Sèrum
# GLUCOSA_SÈRUM
# Son iguales
# GLUCOSA, SUERO
# GLUCOSA_SUERO
# Son iguales
# GOT (AST) SERUM
# GOT_(AST)_SERUM
# Son iguales
# Glucosa sèrum
# GLUCOSA_SÈRUM
# Son iguales
# Glucosa sèrum (2345-7)
# GLUCOSA_SÈRUM_(2345_7)_
# Son iguales
# Glucosa, suero
# GLUCOSA_SUERO
# Son iguales
# Glucosa-Sèrum
# GLUCOSA_SÈRUM
# Son iguales
# HB GLICOSILADA (A1c) Sang
# HB_GLICOSILADA_(A1C)_SANG
# Son iguales
# HEMOGLOBINA GLICOSILADA (HbA1c)
# HEMOGLOBINA_GLICOSILADA_(HBA1C)
# Son iguales
# HIERRO (II+III), SUERO
# HIERRO_(II+III)_SUERO
# Son iguales
# Hb(San)-Glicohemoglobina (A1c)
# HB(SAN)_GLICOHEMOGLOBINA_(A1C)
# Son iguales
# Hb(San)Hemoglobina A1c; fr.subst. (expressat en %)
# HB(SAN)HEMOGLOBINA_A1C_FR_SUBST__(EXPRESSAT_EN_%)
# Son iguales
# Hemoglobina A1c %
# HEMOGLOBINA_A1C_%
# Son iguales
# IÓ POTASSI (SÈRUM); C.SUBST. «PART DE CONJUNT»
# IÓ_POTASSI_(SÈRUM)_C_SUBST__«PART_DE_CONJUNT»
# Son iguales
# IÓ SODI (SÈRUM); C.SUBST. «PART DE CONJUNT»
# IÓ_SODI_(SÈRUM)_C_SUBST__«PART_DE_CONJUNT»
# Son iguales
# LDH (LACTATO DESHIDROGENASA), SUERO
# LDH_(LACTATO_DESHIDROGENASA)_SUERO
# Son iguales
# Lactatodeshidrogenasa (LDH), suero
# LACTATODESHIDROGENASA_(LDH)_SUERO
# Son iguales
# MAGNESI SÈRUM
# MAGNESI_SÈRUM
# Son iguales
# MAGNESIO, SUERO
# MAGNESIO_SUERO
# Son iguales
# Magnesi sèrum
# MAGNESI_SÈRUM
# Son iguales
# Magnesi sèrum (19123-9)
# MAGNESI_SÈRUM_(19123_9)_
# Son iguales
# Magnesio, suero
# MAGNESIO_SUERO
# Son iguales
# Microalbuminuria /L
# MICROALBUMINURIA_/L
# Son iguales
# O Albúmina; c.massa
# O_ALBÚMINA_C_MASSA
# Son iguales
# PCR
# PCR
# NO SON IGUALES
# PCR
# PERFIL-ESTIMACIÓ DEL FILTRAT GLOMERULAR (SEGONS CKD-EPI) EN SÈRUM
# PERFIL_ESTIMACIÓ_DEL_FILTRAT_GLOMERULAR_(SEGONS_CKD_EPI)_EN_SÈRUM
# Son iguales
# POTASIO ION, SUERO
# POTASIO_ION_SUERO
# Son iguales
# POTASSI SERUM
# POTASSI_SERUM
# Son iguales
# POTASSI SÈRUM
# POTASSI_SÈRUM
# Son iguales
# POTASSI Sèrum
# POTASSI_SÈRUM
# Son iguales
# PRECURSOR DEL PÉPTIDO NATRIURÉTICO CEREBRAL (NT-PRO BNP), PLASMA
# PRECURSOR_DEL_PÉPTIDO_NATRIURÉTICO_CEREBRAL_(NT_PRO_BNP)_PLASMA
# Son iguales
# PRECURSOR DEL PÉPTIDO NATRIURÉTICO CEREBRAL (NT-PRO BNP), SUERO
# PRECURSOR_DEL_PÉPTIDO_NATRIURÉTICO_CEREBRAL_(NT_PRO_BNP)_SUERO
# Son iguales
# PROTEINA C REACTIVA
# PROTEINA_C_REACTIVA
# Son iguales
# PROTEINAS TOTALES, SUERO
# PROTEINAS_TOTALES_SUERO
# Son iguales
# PROTEINES TOTALS
# PROTEINES_TOTALS
# Son iguales
# PROTEÍNA C REACTIVA, SUERO
# PROTEÍNA_C_REACTIVA_SUERO
# Son iguales
# PROTEÏNA C REACTIVA (PCR) (SÈRUM); C.MASSA
# PROTEÏNA_C_REACTIVA_(PCR)_(SÈRUM)_C_MASSA
# Son iguales
# PROTEÏNA C REACTIVA Sèrum
# PROTEÏNA_C_REACTIVA_SÈRUM
# Son iguales
# PROTEÏNES TOTALS Sèrum
# PROTEÏNES_TOTALS_SÈRUM
# Son iguales
# Pac-Filtrat glomerular (estimació segons CKD-EPI)
# PAC_FILTRAT_GLOMERULAR_(ESTIMACIÓ_SEGONS_CKD_EPI)
# Son iguales
# Pac-Filtrat glomerular (estimació segons CKD-EPI)
# PAC_FILTRAT_GLOMERULAR_(ESTIMACIÓ_SEGONS_CKD_EPI)_
# Son iguales
# PlaDímer D de la fibrina; c.massa (immunoquímica)
# PLADÍMER_D_DE_LA_FIBRINA_C_MASSA_(IMMUNOQUÍMICA)
# Son iguales
# PlaPro-Pèptid natriurètic cerebral (1-76); c.massa
# PLAPRO_PÈPTID_NATRIURÈTIC_CEREBRAL_(1_76)_C_MASSA
# Son iguales
# Pla_Troponina I alta sensibilitat (VRef <45 ng/L)
# PLA_TROPONINA_I_ALTA_SENSIBILITAT_(VREF_<45_NG/L)
# Son iguales
# Potasio, suero
# POTASIO_SUERO
# Son iguales
# Potassi
# POTASSI
# Son iguales
# Potassi (2823-3)
# POTASSI_(2823_3)_
# Son iguales
# Potassi-Sèrum
# POTASSI_SÈRUM
# Son iguales
# Proteínas, suero
# PROTEÍNAS_SUERO
# Son iguales
# Proteïna C reactiva
# PROTEÏNA_C_REACTIVA
# Son iguales
# Proteïna C reactiva sèrum
# PROTEÏNA_C_REACTIVA_SÈRUM
# Son iguales
# Proteïna C reactiva sèrum (1988-5)
# PROTEÏNA_C_REACTIVA_SÈRUM_(1988_5)_
# Son iguales
# Proteïna C reactiva-Sèrum
# PROTEÏNA_C_REACTIVA_SÈRUM
# Son iguales
# Proteïna-Sèrum
# PROTEÏNA_SÈRUM
# Son iguales
# Proteïnes totals sèrum
# PROTEÏNES_TOTALS_SÈRUM
# Son iguales
# Proteïnes totals sèrum (2885-2)
# PROTEÏNES_TOTALS_SÈRUM_(2885_2)_
# Son iguales
# SIDEREMIA
# SIDEREMIA
# Son iguales
# SODI SERUM
# SODI_SERUM
# Son iguales
# SODI SÈRUM
# SODI_SÈRUM
# Son iguales
# SODI Sèrum
# SODI_SÈRUM
# Son iguales
# SODIO ION, SUERO
# SODIO_ION_SUERO
# Son iguales
# Sodi
# SODI
# Son iguales
# Sodi (2951-2)
# SODI_(2951_2)_
# Son iguales
# Sodi-Sèrum
# SODI_SÈRUM
# Son iguales
# Sodio, suero
# SODIO_SUERO
# Son iguales
# Srm-ALANINA AMINOTRANSFERASA; c.cat
# SRM_ALANINA_AMINOTRANSFERASA_C_CAT
# Son iguales
# Srm-Alanina aminotransferasa
# SRM_ALANINA_AMINOTRANSFERASA
# Son iguales
# Srm-Alanina-aminotransferasa
# SRM_ALANINA_AMINOTRANSFERASA
# Son iguales
# Srm-Alanina-aminotransferasa; b
# SRM_ALANINA_AMINOTRANSFERASA_B
# Son iguales
# Srm-Aspartat aminotransferasa
# SRM_ASPARTAT_AMINOTRANSFERASA
# Son iguales
# Srm-Aspartat-aminotransferasa
# SRM_ASPARTAT_AMINOTRANSFERASA
# Son iguales
# Srm-Bilirubina
# SRM_BILIRUBINA
# Son iguales
# Srm-Bilirubina total
# SRM_BILIRUBINA_TOTAL
# Son iguales
# Srm-CLORUR; c.subst.
# SRM_CLORUR_C_SUBST_
# Son iguales
# Srm-CREATININI
# SRM_CREATININI
# Son iguales
# Srm-Calci
# SRM_CALCI
# Son iguales
# Srm-Clorur
# SRM_CLORUR
# Son iguales
# Srm-Clorur; c
# SRM_CLORUR_C
# Son iguales
# Srm-Creatina-cinasa
# SRM_CREATINA_CINASA
# Son iguales
# Srm-Creatinina
# SRM_CREATININA
# Son iguales
# Srm-Creatinini; c
# SRM_CREATININI_C
# Son iguales
# Srm-Ferritina
# SRM_FERRITINA
# Son iguales
# Srm-Ferro
# SRM_FERRO
# Son iguales
# Srm-Fosfatasa alcalina
# SRM_FOSFATASA_ALCALINA
# Son iguales
# Srm-GLUCOSA; c.subst.
# SRM_GLUCOSA_C_SUBST_
# Son iguales
# Srm-Glucosa
# SRM_GLUCOSA
# Son iguales
# Srm-Glucosa; c
# SRM_GLUCOSA_C
# Son iguales
# Srm-IO POTASSI; c.subst.
# SRM_IO_POTASSI_C_SUBST_
# Son iguales
# Srm-IO SODI,c
# SRM_IO_SODIC
# Son iguales
# Srm-Ió Potassi
# SRM_IÓ_POTASSI
# Son iguales
# Srm-Ió Sodi
# SRM_IÓ_SODI
# Son iguales
# Srm-Ió potassi
# SRM_IÓ_POTASSI
# Son iguales
# Srm-Ió potassi; c
# SRM_IÓ_POTASSI_C
# Son iguales
# Srm-Ió sodi
# SRM_IÓ_SODI
# Son iguales
# Srm-Ió sodi; c
# SRM_IÓ_SODI_C
# Son iguales
# Srm-Lactat-deshidrogenasa
# SRM_LACTAT_DESHIDROGENASA
# Son iguales
# Srm-Magnesi
# SRM_MAGNESI
# Son iguales
# Srm-PROTEÏNA C REACTIVA (PCR); c.massa
# SRM_PROTEÏNA_C_REACTIVA_(PCR)_C_MASSA
# Son iguales
# Srm-Proteïna
# SRM_PROTEÏNA
# Son iguales
# Srm-Proteïna C reactiva
# SRM_PROTEÏNA_C_REACTIVA
# Son iguales
# Srm-Troponina I alta sensibilitat
# SRM_TROPONINA_I_ALTA_SENSIBILITAT
# Son iguales
# Srm-Troponina I alta sensibilitat
# SRM_TROPONINA_I_ALTA_SENSIBILITAT_
# Son iguales
# Srm-UREA; c.subst.
# SRM_UREA_C_SUBST_
# Son iguales
# Srm-Urea
# SRM_UREA
# Son iguales
# SrmAlanina-aminotransferasa; c.cat.
# SRMALANINA_AMINOTRANSFERASA_C_CAT_
# Son iguales
# SrmAspartat-aminotransferasa; c.cat.
# SRMASPARTAT_AMINOTRANSFERASA_C_CAT_
# Son iguales
# SrmBilirubina; c.subst.
# SRMBILIRUBINA_C_SUBST_
# Son iguales
# SrmCalci(II); c.subst.
# SRMCALCI(II)_C_SUBST_
# Son iguales
# SrmClorur; c.subst.
# SRMCLORUR_C_SUBST_
# Son iguales
# SrmCreatinini; c.subst.
# SRMCREATININI_C_SUBST_
# Son iguales
# SrmFerritina; c.massa
# SRMFERRITINA_C_MASSA
# Son iguales
# SrmFosfatasa alcalina; c.cat.
# SRMFOSFATASA_ALCALINA_C_CAT_
# Son iguales
# SrmGlucosa; c.subst.
# SRMGLUCOSA_C_SUBST_
# Son iguales
# SrmIó potassi; c.subst.
# SRMIÓ_POTASSI_C_SUBST_
# Son iguales
# SrmIó sodi; c.subst.
# SRMIÓ_SODI_C_SUBST_
# Son iguales
# SrmProteïna; c.massa
# SRMPROTEÏNA_C_MASSA
# Son iguales
# SrmUrea; c.subst.
# SRMUREA_C_SUBST_
# Son iguales
# Srm_Alanina-aminotransferasa; c. cat. (IFCC)
# SRM_ALANINA_AMINOTRANSFERASA_C__CAT__(IFCC)
# Son iguales
# Srm_Alanina-aminotransferasa; c. cat.#(IFCC)
# SRM_ALANINA_AMINOTRANSFERASA_C__CAT_#(IFCC)
# Son iguales
# Srm_Bilirubina; c.subst.
# SRM_BILIRUBINA_C_SUBST_
# Son iguales
# Srm_Calci; c.subst.
# SRM_CALCI_C_SUBST_
# Son iguales
# Srm_Creatinini; c.subst.
# SRM_CREATININI_C_SUBST_
# Son iguales
# Srm_Ferritina; c.massa
# SRM_FERRITINA_C_MASSA
# Son iguales
# Srm_Ferro; c.subst.
# SRM_FERRO_C_SUBST_
# Son iguales
# Srm_Fosfatasa alcalina; c.cat. (IFCC)
# SRM_FOSFATASA_ALCALINA_C_CAT__(IFCC)
# Son iguales
# Srm_Fosfatasa alcalina; c.cat.#(IFCC)
# SRM_FOSFATASA_ALCALINA_C_CAT_#(IFCC)
# Son iguales
# Srm_Glucosa; c.subst.
# SRM_GLUCOSA_C_SUBST_
# Son iguales
# Srm_Ió potassi; c.subst.
# SRM_IÓ_POTASSI_C_SUBST_
# Son iguales
# Srm_Ió sodi; c.subst.
# SRM_IÓ_SODI_C_SUBST_
# Son iguales
# Srm_Lactat-deshidrogenasa; c.cat. #(IFCC)
# SRM_LACTAT_DESHIDROGENASA_C_CAT__#(IFCC)
# Son iguales
# Srm_Proteïna C reactiva   c.massa
# SRM_PROTEÏNA_C_REACTIVA___C_MASSA
# Son iguales
# Srm_Proteïna C reactiva # c.massa
# SRM_PROTEÏNA_C_REACTIVA_#_C_MASSA
# Son iguales
# Srm_Proteïna; c.massa
# SRM_PROTEÏNA_C_MASSA
# Son iguales
# Srm_Urea; c.subst.   (mesurada com a Nitrogen Ureic - BUN)
# SRM_UREA_C_SUBST____(MESURADA_COM_A_NITROGEN_UREIC___BUN)
# Son iguales
# Srm_Urea; c.subst. # (mesurada com a Nitrogen Ureic - BUN)
# SRM_UREA_C_SUBST__#_(MESURADA_COM_A_NITROGEN_UREIC___BUN)
# Son iguales
# Srml-Lactat-deshidrogenasa; c.cat.
# SRML_LACTAT_DESHIDROGENASA_C_CAT_
# Son iguales
# UREA (SÈRUM); C.SUBST
# UREA_(SÈRUM)_C_SUBST
# Son iguales
# UREA SERUM
# UREA_SERUM
# Son iguales
# UREA SÈRUM
# UREA_SÈRUM
# Son iguales
# UREA Sèrum
# UREA_SÈRUM
# Son iguales
# UREA, SUERO
# UREA_SUERO
# Son iguales
# Urea sèrum
# UREA_SÈRUM
# Son iguales
# Urea sèrum (3091-6)
# UREA_SÈRUM_(3091_6)_
# Son iguales
# Urea-Sèrum
# UREA_SÈRUM
# Son iguales
# Uri-Albúmina orina recent
# URI_ALBÚMINA_ORINA_RECENT
# Son iguales
# Activitat exercici en consulta
# ACTIVITAT_EXERCICI_EN_CONSULTA
# Son iguales
# Ara fuma?
# ARA_FUMA?
# Son iguales
# Cigarretes/dia
# CIGARRETES/DIA
# Son iguales
# Colesterol total
# COLESTEROL_TOTAL
# Son iguales
# Consell consum d'alcohol
# CONSELL_CONSUM_D'ALCOHOL
# Son iguales
# Cribratge abús alcohol (Audit-C)
# CRIBRATGE_ABÚS_ALCOHOL_(AUDIT_C)
# Son iguales
# Cribratge alimentació
# CRIBRATGE_ALIMENTACIÓ
# Son iguales
# Etapa canvi. Activitat física
# ETAPA_CANVI__ACTIVITAT_FÍSICA
# Son iguales
# Freqüència cardíaca
# FREQÜÈNCIA_CARDÍACA
# Son iguales
# Glicèmia venosa dejú
# GLICÈMIA_VENOSA_DEJÚ
# Son iguales
# IMC - Índex de Massa Corporal
# IMC___ÍNDEX_DE_MASSA_CORPORAL
# Son iguales
# Motivació tabac
# MOTIVACIÓ_TABAC
# Son iguales
# Paquets/any consumits
# PAQUETS/ANY_CONSUMITS
# Son iguales
# Pes
# PES
# Son iguales
# Potasi (K) Sèric
# POTASI_(K)_SÈRIC
# Son iguales
# Pressió Arterial Diastòlica
# PRESSIÓ_ARTERIAL_DIASTÒLICA
# Son iguales
# Pressió Arterial Sistòlica
# PRESSIÓ_ARTERIAL_SISTÒLICA
# Son iguales
# Qüestionari CBPAAT d'activitat física
# QÜESTIONARI_CBPAAT_D'ACTIVITAT_FÍSICA
# Son iguales
# Ritme cardíac
# RITME_CARDÍAC
# Son iguales
# Sedestació interrompuda
# SEDESTACIÓ_INTERROMPUDA
# Son iguales
# Temps assegut (h/d)
# TEMPS_ASSEGUT_(H/D)
# Son iguales
# Test dep. nicotina (Fagerström) breu
# TEST_DEP__NICOTINA_(FAGERSTRÖM)_BREU
# Son iguales
# Tipus d'exposició ambiental de tabac
# TIPUS_D'EXPOSICIÓ_AMBIENTAL_DE_TABAC
# Son iguales
# Tipus d'intervenció tabac
# TIPUS_D'INTERVENCIÓ_TABAC
# Son iguales
# Tipus de tabac
# TIPUS_DE_TABAC
# NO SON IGUALES
# Tipus de tabac
# Valoració resultat AUDIT-C
# VALORACIÓ_RESULTAT_AUDIT_C
# Son iguales
# Voldria deixar de fumar?
# VOLDRIA_DEIXAR_DE_FUMAR?
# Son iguales
#     Basòfils
# ____BASÒFILS
# Son iguales
#     Eosinòfils
# ____EOSINÒFILS
# Son iguales
#     Limfòcits
# ____LIMFÒCITS
# Son iguales
#     Monòcits
# ____MONÒCITS
# Son iguales
#     Neutròfils segmentats
# ____NEUTRÒFILS_SEGMENTATS
# Son iguales
#   Amplitud distribució eritrocitària (ADE)
# __AMPLITUD_DISTRIBUCIÓ_ERITROCITÀRIA_(ADE)
# Son iguales
#   Conc. hemoglobina corpuscular mitjana (CHCM)
# __CONC__HEMOGLOBINA_CORPUSCULAR_MITJANA_(CHCM)
# Son iguales
#   Hematíes
# __HEMATÍES
# Son iguales
#   Hematòcrit
# __HEMATÒCRIT
# Son iguales
#   Hemoglobina
# __HEMOGLOBINA
# Son iguales
#   Hemoglobina corpuscular mitja (HCM)
# __HEMOGLOBINA_CORPUSCULAR_MITJA_(HCM)
# Son iguales
#   Leucòcits
# __LEUCÒCITS
# Son iguales
#   Plaquetes
# __PLAQUETES
# Son iguales
#   Volum corpuscular mig (VCM)
# __VOLUM_CORPUSCULAR_MIG_(VCM)
# Son iguales
#   Volum plaquetar mig (VPM)
# __VOLUM_PLAQUETAR_MIG_(VPM)
# Son iguales
# Ample Distribució Eritrocits (ADE)
# AMPLE_DISTRIBUCIÓ_ERITROCITS_(ADE)
# Son iguales
# Amplitud de distribució eritrocitària-Sang
# AMPLITUD_DE_DISTRIBUCIÓ_ERITROCITÀRIA_SANG
# Son iguales
# Amplitud de distribució plaquetària-Sang
# AMPLITUD_DE_DISTRIBUCIÓ_PLAQUETÀRIA_SANG
# Son iguales
# BASOFILS:(%)
# BASOFILS:(%)
# Son iguales
# BASÒFILS %
# BASÒFILS_%
# Son iguales
# BASÒFILS (HEMOGRAMA); FR.NOM. «PART DE CONJUNT»
# BASÒFILS_(HEMOGRAMA)_FR_NOM__«PART_DE_CONJUNT»
# Son iguales
# Basòfils
# BASÒFILS
# Son iguales
# Basòfils   %
# BASÒFILS___%
# Son iguales
# Basòfils   % (706-2)
# BASÒFILS___%_(706_2)_
# Son iguales
# Basòfils %
# BASÒFILS_%
# Son iguales
# Basòfils %-Sang
# BASÒFILS_%_SANG
# Son iguales
# Basófilos %
# BASÓFILOS_%
# Son iguales
# Basófilos aut%
# BASÓFILOS_AUT%
# Son iguales
# C H C M
# C_H_C_M
# Son iguales
# CCMH
# CCMH
# Son iguales
# CHCM
# CHCM
# NO SON IGUALES
# CHCM
# CHCM (786-4)
# CHCM_(786_4)_
# Son iguales
# Conc.Hb.Corpuscular Media
# CONC_HB_CORPUSCULAR_MEDIA
# Son iguales
# Concentració HGB Corpuscular mitja
# CONCENTRACIÓ_HGB_CORPUSCULAR_MITJA
# Son iguales
# Concentració Hemoglobina corpuscular mitjana-Sang
# CONCENTRACIÓ_HEMOGLOBINA_CORPUSCULAR_MITJANA_SANG
# Son iguales
# EOSINOFILS:(%)
# EOSINOFILS:(%)
# Son iguales
# EOSINÒFILS %
# EOSINÒFILS_%
# Son iguales
# EOSINÒFILS (HEMOGRAMA); FR.NOM. «PART DE CONJUNT»
# EOSINÒFILS_(HEMOGRAMA)_FR_NOM__«PART_DE_CONJUNT»
# Son iguales
# ERITRÒCITS (HEMOGRAMA); C.NOM. «PART DE CONJUNT»
# ERITRÒCITS_(HEMOGRAMA)_C_NOM__«PART_DE_CONJUNT»
# Son iguales
# ERITRÒCITS (HEMOGRAMA); COEFICIENT VARIACIÓ VOL.ENTÍTIC (RDW, ADE). «PART DE CONJUNT»
# ERITRÒCITS_(HEMOGRAMA)_COEFICIENT_VARIACIÓ_VOL_ENTÍTIC_(RDW_ADE)__«PART_DE_CONJUNT»
# Son iguales
# ERITRÒCITS (HEMOGRAMA); VOL.ENTÍTIC (VCM). «PART DE CONJUNT»
# ERITRÒCITS_(HEMOGRAMA)_VOL_ENTÍTIC_(VCM)__«PART_DE_CONJUNT»
# Son iguales
# Eosinòfils %
# EOSINÒFILS_%
# Son iguales
# Eosinòfils % (713-8)
# EOSINÒFILS_%_(713_8)_
# Son iguales
# Eosinòfils %-Sang
# EOSINÒFILS_%_SANG
# Son iguales
# Eosinófilos %
# EOSINÓFILOS_%
# Son iguales
# Eosinófilos aut%
# EOSINÓFILOS_AUT%
# Son iguales
# Eritròcits
# ERITRÒCITS
# Son iguales
# Eritròcits-Sang
# ERITRÒCITS_SANG
# Son iguales
# Ers(San)-A. D. E.
# ERS(SAN)_A__D__E_
# Son iguales
# Ers(San)-C. H. C. M.
# ERS(SAN)_C__H__C__M_
# Son iguales
# Ers(San)-Conc.corp. mitjana Hb (CCMH); g
# ERS(SAN)_CONC_CORP__MITJANA_HB_(CCMH)_G
# Son iguales
# Ers(San)-H. C. M.
# ERS(SAN)_H__C__M_
# Son iguales
# Ers(San)-Hb. corp. mitjana (HCM); m
# ERS(SAN)_HB__CORP__MITJANA_(HCM)_M
# Son iguales
# Ers(San)-Hemoglobina; g
# ERS(SAN)_HEMOGLOBINA_G
# Son iguales
# Ers(San)-V. C. M.
# ERS(SAN)_V__C__M_
# Son iguales
# Ers(San)-Vol. corp.mitjà (VCM); V
# ERS(SAN)_VOL__CORP_MITJÀ_(VCM)_V
# Son iguales
# Ers(San)-Volum eritrocític; A.D.(CV)
# ERS(SAN)_VOLUM_ERITROCÍTIC_A_D_(CV)
# Son iguales
# Ers(San)Hemoglobina; c.massa ("CHCM")
# ERS(SAN)HEMOGLOBINA_C_MASSA_("CHCM")
# Son iguales
# Ers(San)Hemoglobina; massa entítica ("HCM")
# ERS(SAN)HEMOGLOBINA_MASSA_ENTÍTICA_("HCM")
# Son iguales
# Ers(San)Volum eritrocític; amplada de la distribució rel.
# ERS(SAN)VOLUM_ERITROCÍTIC_AMPLADA_DE_LA_DISTRIBUCIÓ_REL_
# Son iguales
# Ers(San)_Hemoglobina;c.massa (CCMH)
# ERS(SAN)_HEMOGLOBINAC_MASSA_(CCMH)
# Son iguales
# Ers(San)_Hemoglobina;massa entítica (HCM)
# ERS(SAN)_HEMOGLOBINAMASSA_ENTÍTICA_(HCM)
# Son iguales
# H. C. M.
# H__C__M_
# Son iguales
# HCM
# HCM
# NO SON IGUALES
# HCM
# HEMATIES
# HEMATIES
# Son iguales
# HEMATOCRIT
# HEMATOCRIT
# NO SON IGUALES
# HEMATOCRIT
# HEMATÒCRIT
# HEMATÒCRIT
# Son iguales
# HEMATÒCRIT (S.VENOSA); FR.VOL. «PART DE CONJUNT»
# HEMATÒCRIT_(S_VENOSA)_FR_VOL__«PART_DE_CONJUNT»
# Son iguales
# HEMOGLOBINA
# HEMOGLOBINA
# Son iguales
# HEMOGLOBINA (CCMH) (HEMOGRAMA); C.MASSA. «PART DE CONJUNT»
# HEMOGLOBINA_(CCMH)_(HEMOGRAMA)_C_MASSA__«PART_DE_CONJUNT»
# Son iguales
# HEMOGLOBINA (HCM) (HEMOGRAMA); MASSA ENTÍTICA. «PART DE CONJUNT»
# HEMOGLOBINA_(HCM)_(HEMOGRAMA)_MASSA_ENTÍTICA__«PART_DE_CONJUNT»
# Son iguales
# HEMOGLOBINA (HEMOGRAMA); C.MASSA. «PART DE CONJUNT»
# HEMOGLOBINA_(HEMOGRAMA)_C_MASSA__«PART_DE_CONJUNT»
# Son iguales
# Hb.Corpuscular Media
# HB_CORPUSCULAR_MEDIA
# Son iguales
# Hematies
# HEMATIES
# Son iguales
# Hematies (789-8)
# HEMATIES_(789_8)_
# Son iguales
# Hematocrito
# HEMATOCRITO
# Son iguales
# Hematíes
# HEMATÍES
# Son iguales
# Hematòcrit
# HEMATÒCRIT
# Son iguales
# Hematòcrit (4544-3)
# HEMATÒCRIT_(4544_3)_
# Son iguales
# Hematòcrit-Sang
# HEMATÒCRIT_SANG
# Son iguales
# Hemoglobina
# HEMOGLOBINA
# Son iguales
# Hemoglobina (718-7)
# HEMOGLOBINA_(718_7)_
# Son iguales
# Hemoglobina corpuscular mitja (HCM)
# HEMOGLOBINA_CORPUSCULAR_MITJA_(HCM)
# Son iguales
# Hemoglobina corpuscular mitjana-Sang
# HEMOGLOBINA_CORPUSCULAR_MITJANA_SANG
# Son iguales
# Hemoglobina-Sang
# HEMOGLOBINA_SANG
# Son iguales
# LEUCOCITS
# LEUCOCITS
# NO SON IGUALES
# LEUCOCITS
# LEUCÒCITS
# LEUCÒCITS
# Son iguales
# LEUCÒCITS (HEMOGRAMA); C.NOM. «PART DE CONJUNT»
# LEUCÒCITS_(HEMOGRAMA)_C_NOM__«PART_DE_CONJUNT»
# Son iguales
# LIMFOCITS:(%)
# LIMFOCITS:(%)
# Son iguales
# LIMFÒCITS %
# LIMFÒCITS_%
# Son iguales
# LIMFÒCITS (HEMOGRAMA); FR.NOM. «PART DE CONJUNT»
# LIMFÒCITS_(HEMOGRAMA)_FR_NOM__«PART_DE_CONJUNT»
# Son iguales
# Leucocitos
# LEUCOCITOS
# Son iguales
# Leucòcits
# LEUCÒCITS
# Son iguales
# Leucòcits (6690-2)
# LEUCÒCITS_(6690_2)_
# Son iguales
# Leucòcits-Sang
# LEUCÒCITS_SANG
# Son iguales
# Limfòcits
# LIMFÒCITS
# Son iguales
# Limfòcits %
# LIMFÒCITS_%
# Son iguales
# Limfòcits % (736-9)
# LIMFÒCITS_%_(736_9)_
# Son iguales
# Limfòcits %-Sang
# LIMFÒCITS_%_SANG
# Son iguales
# Linfocitos %
# LINFOCITOS_%
# Son iguales
# Linfocitos aut%
# LINFOCITOS_AUT%
# Son iguales
# Lks(San)-Basòfils; q
# LKS(SAN)_BASÒFILS_Q
# Son iguales
# Lks(San)-Eosinòfils; q
# LKS(SAN)_EOSINÒFILS_Q
# Son iguales
# Lks(San)-Limfòcits; q
# LKS(SAN)_LIMFÒCITS_Q
# Son iguales
# Lks(San)-Monòcits; q
# LKS(SAN)_MONÒCITS_Q
# Son iguales
# Lks(San)-Neutròfils; q
# LKS(SAN)_NEUTRÒFILS_Q
# Son iguales
# Lks(San)Basòfils; fr.nom.
# LKS(SAN)BASÒFILS_FR_NOM_
# Son iguales
# Lks(San)Eosinòfils; fr.nom.
# LKS(SAN)EOSINÒFILS_FR_NOM_
# Son iguales
# Lks(San)Limfòcits; fr.nom.
# LKS(SAN)LIMFÒCITS_FR_NOM_
# Son iguales
# Lks(San)Monòcits; fr.nom.
# LKS(SAN)MONÒCITS_FR_NOM_
# Son iguales
# Lks(San)Neutròfils(segmentats); fr.nom.
# LKS(SAN)NEUTRÒFILS(SEGMENTATS)_FR_NOM_
# Son iguales
# Lks(San)_Basòfils;fr.nom.
# LKS(SAN)_BASÒFILSFR_NOM_
# Son iguales
# Lks(San)_Eosinòfils;fr.nom.
# LKS(SAN)_EOSINÒFILSFR_NOM_
# Son iguales
# Lks(San)_Limfòcits;fr.nom.
# LKS(SAN)_LIMFÒCITSFR_NOM_
# Son iguales
# Lks(San)_Monòcits;fr.nom.
# LKS(SAN)_MONÒCITSFR_NOM_
# Son iguales
# Lks(San)_Neutròfils;fr.nom.
# LKS(SAN)_NEUTRÒFILSFR_NOM_
# Son iguales
# M. C. H. C.
# M__C__H__C_
# Son iguales
# M.C.H.
# M_C_H_
# Son iguales
# M.C.H.C.
# M_C_H_C_
# Son iguales
# MONOCITS:(%)
# MONOCITS:(%)
# Son iguales
# MONÒCITS %
# MONÒCITS_%
# Son iguales
# MONÒCITS (HEMOGRAMA); FR.NOM. «PART DE CONJUNT»
# MONÒCITS_(HEMOGRAMA)_FR_NOM__«PART_DE_CONJUNT»
# Son iguales
# Monocitos %
# MONOCITOS_%
# Son iguales
# Monocitos aut%
# MONOCITOS_AUT%
# Son iguales
# Monòcits
# MONÒCITS
# Son iguales
# Monòcits   %
# MONÒCITS___%
# Son iguales
# Monòcits   % (5905-5)
# MONÒCITS___%_(5905_5)_
# Son iguales
# Monòcits %
# MONÒCITS_%
# Son iguales
# Monòcits %-Sang
# MONÒCITS_%_SANG
# Son iguales
# NEUTROFILS:(%)
# NEUTROFILS:(%)
# Son iguales
# NEUTRÒFILS %
# NEUTRÒFILS_%
# Son iguales
# NEUTRÒFILS (HEMOGRAMA); FR.NOM. «PART DE CONJUNT»
# NEUTRÒFILS_(HEMOGRAMA)_FR_NOM__«PART_DE_CONJUNT»
# Son iguales
# Neutròfils
# NEUTRÒFILS
# Son iguales
# Neutròfils %
# NEUTRÒFILS_%
# Son iguales
# Neutròfils % (770-8)
# NEUTRÒFILS_%_(770_8)_
# Son iguales
# Neutròfils %-Sang
# NEUTRÒFILS_%_SANG
# Son iguales
# Neutrófilos aut %
# NEUTRÓFILOS_AUT_%
# Son iguales
# Neutrófilos segmentados %
# NEUTRÓFILOS_SEGMENTADOS_%
# Son iguales
# P. D. W.
# P__D__W_
# Son iguales
# PDW
# PDW
# Son iguales
# PLAQUETAS
# PLAQUETAS
# Son iguales
# PLAQUETES
# PLAQUETES
# Son iguales
# PLAQUETES;C.NOM. «PART DE CONJUNT»
# PLAQUETESC_NOM__«PART_DE_CONJUNT»
# Son iguales
# Pla(San)-Volum plaquetari mitjà (VPM); V
# PLA(SAN)_VOLUM_PLAQUETARI_MITJÀ_(VPM)_V
# Son iguales
# Plaquetas
# PLAQUETAS
# Son iguales
# Plaquetes
# PLAQUETES
# Son iguales
# Plaquetes (777-3)
# PLAQUETES_(777_3)_
# Son iguales
# Plaquetes-Sang
# PLAQUETES_SANG
# Son iguales
# Pqs(San)-V. P. M.
# PQS(SAN)_V__P__M__
# Son iguales
# R.D.W.
# R_D_W_
# Son iguales
# RDW
# RDW
# Son iguales
# RDW - CV
# RDW___CV
# Son iguales
# RDW-CV
# RDW_CV
# Son iguales
# RDW-CV (788-0)
# RDW_CV_(788_0)_
# Son iguales
# RDW-SD
# RDW_SD
# Son iguales
# San Lks-BASÒFILS, w
# SAN_LKS_BASÒFILS_W
# Son iguales
# San Lks-EOSINÒFILS, w
# SAN_LKS_EOSINÒFILS_W
# Son iguales
# San Lks-LIMFÒCITS, w
# SAN_LKS_LIMFÒCITS_W
# Son iguales
# San Lks-MONÒCITS, w
# SAN_LKS_MONÒCITS_W
# Son iguales
# San Lks-NEUTRÒFILS, w
# SAN_LKS_NEUTRÒFILS_W
# Son iguales
# San-Basòfils
# SAN_BASÒFILS
# Son iguales
# San-CONC.HGB.CORP. MITJA, p
# SAN_CONC_HGB_CORP__MITJA_P
# Son iguales
# San-ERITRÒCITS, c
# SAN_ERITRÒCITS_C
# Son iguales
# San-Eosinòfils
# SAN_EOSINÒFILS
# Son iguales
# San-Eritròcits
# SAN_ERITRÒCITS
# Son iguales
# San-HEMATÒCRIT, h
# SAN_HEMATÒCRIT_H
# Son iguales
# San-HEMOGLOBINA CORP.MITJANA,m
# SAN_HEMOGLOBINA_CORP_MITJANAM
# Son iguales
# San-HEMOGLOBINA, p
# SAN_HEMOGLOBINA_P
# Son iguales
# San-Hematòcrit
# SAN_HEMATÒCRIT
# Son iguales
# San-Hematòcrit; h
# SAN_HEMATÒCRIT_H
# Son iguales
# San-Hemoglobina
# SAN_HEMOGLOBINA
# Son iguales
# San-LEUCÒCITS, c
# SAN_LEUCÒCITS_C
# Son iguales
# San-Leucòcits
# SAN_LEUCÒCITS
# Son iguales
# San-Leucòcits; C
# SAN_LEUCÒCITS_C
# Son iguales
# San-Limfòcits
# SAN_LIMFÒCITS
# Son iguales
# San-Monòcits
# SAN_MONÒCITS
# Son iguales
# San-Neutròfils
# SAN_NEUTRÒFILS
# Son iguales
# San-PLAQUETES, c
# SAN_PLAQUETES_C
# Son iguales
# San-Plaquetes
# SAN_PLAQUETES
# Son iguales
# San-Plaquetes; C
# SAN_PLAQUETES_C
# Son iguales
# San-VOLUM CORPUSCULAR MITJÀ, v
# SAN_VOLUM_CORPUSCULAR_MITJÀ_V
# Son iguales
# San-VOLUM PLAQUETARI MITJÀ
# SAN_VOLUM_PLAQUETARI_MITJÀ
# Son iguales
# SanEritròcits; c.nom.
# SANERITRÒCITS_C_NOM_
# Son iguales
# SanEritròcits; fr.vol.(hematòcrit)
# SANERITRÒCITS_FR_VOL_(HEMATÒCRIT)
# Son iguales
# SanEritròcits; vol.entític ("VCM")
# SANERITRÒCITS_VOL_ENTÍTIC_("VCM")
# Son iguales
# SanHemoglobina; c.massa
# SANHEMOGLOBINA_C_MASSA
# Son iguales
# SanLeucòcits; c.nom.
# SANLEUCÒCITS_C_NOM_
# Son iguales
# SanPlaquetes; c.nom.
# SANPLAQUETES_C_NOM_
# Son iguales
# SanPlaquetes; vol.entític ("VPM")
# SANPLAQUETES_VOL_ENTÍTIC_("VPM")
# Son iguales
# San_Eritròcits;c.nom.
# SAN_ERITRÒCITSC_NOM_
# Son iguales
# San_Eritròcits;coeficient variació  vol.entític (RDW, ADE)
# SAN_ERITRÒCITSCOEFICIENT_VARIACIÓ__VOL_ENTÍTIC_(RDW_ADE)
# Son iguales
# San_Eritròcits;coeficient variació# vol.entític (RDW, ADE)
# SAN_ERITRÒCITSCOEFICIENT_VARIACIÓ#_VOL_ENTÍTIC_(RDW_ADE)
# Son iguales
# San_Eritròcits;fr.vol. (Hematòcrit)
# SAN_ERITRÒCITSFR_VOL__(HEMATÒCRIT)
# Son iguales
# San_Eritròcits;vol.entític (VCM)
# SAN_ERITRÒCITSVOL_ENTÍTIC_(VCM)
# Son iguales
# San_Hemoglobina; c.massa
# SAN_HEMOGLOBINA_C_MASSA
# Son iguales
# San_Leucòcits;c.nom.
# SAN_LEUCÒCITSC_NOM_
# Son iguales
# San_Plaquetes;c.nom.
# SAN_PLAQUETESC_NOM_
# Son iguales
# San_Plaquetes;vol.entític (VPM)
# SAN_PLAQUETESVOL_ENTÍTIC_(VPM)
# Son iguales
# V C M
# V_C_M
# Son iguales
# V. C. M.
# V__C__M_
# Son iguales
# V. P. M.
# V__P__M_
# Son iguales
# VCM
# VCM
# Son iguales
# VCM (787-2)
# VCM_(787_2)_
# Son iguales
# VOLUM CORPUSCULAR MIG
# VOLUM_CORPUSCULAR_MIG
# Son iguales
# VOLUM PLAQUETAR MIG
# VOLUM_PLAQUETAR_MIG
# Son iguales
# VPM
# VPM
# Son iguales
# Volum corpuscular mig (VCM)
# VOLUM_CORPUSCULAR_MIG_(VCM)
# Son iguales
# Volum corpuscular mitjà-Sang
# VOLUM_CORPUSCULAR_MITJÀ_SANG
# Son iguales
# Volum plaquetari mig
# VOLUM_PLAQUETARI_MIG
# Son iguales
# Volum plaquetari mitjà-Sang
# VOLUM_PLAQUETARI_MITJÀ_SANG
# Son iguales
# Volumen corpuscular medio
# VOLUMEN_CORPUSCULAR_MEDIO
# Son iguales
# DIAGNÒSTIC ASSOCIAT
# DIAGNÒSTIC_ASSOCIAT
# Son iguales
# Columnes estandarditzades. 472 columnes originals -> 67 columnes netes.
# Fusió completada. Files originals: 133. Registres únics de pacient: 133.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 67 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   CODI_PACIENT                   133 non-null    object
#  1   INR                            133 non-null    float64
#  2   ALT_GPT                        103 non-null    float64
#  3   MICROALBUMINURIA               70 non-null     float64
#  4   AST_GOT                        70 non-null     float64
#  5   BILIRUBINA_TOTAL               68 non-null     float64
#  6   CALCI                          66 non-null     float64
#  7   CLORUR                         22 non-null     float64
#  8   CREATINA_KINASA_CK             16 non-null     float64
#  9   CREATININA                     117 non-null    float64
#  10  FERRITINA                      70 non-null     float64
#  11  FG_CKD_EPI                     93 non-null     float64
#  12  FOSFATASA_ALCALINA             66 non-null     float64
#  13  FERRO                          50 non-null     float64
#  14  GLUCOSA                        117 non-null    float64
#  15  HB_GLICOSILADA_A1C             24 non-null     float64
#  16  HEMOGLOBINA                    116 non-null    float64
#  17  POTASSI                        113 non-null    float64
#  18  SODI                           113 non-null    float64
#  19  LDH                            8 non-null      float64
#  20  MAGNESI                        16 non-null     float64
#  21  NT_PROBNP                      34 non-null     float64
#  22  PCR                            70 non-null     float64
#  23  PROTEINES_TOTALS               53 non-null     float64
#  24  DIMER_D                        0 non-null      float64
#  25  TROPONINA_I_ALTA_SENSIBILITAT  2 non-null      float64
#  26  UREA                           77 non-null     float64
#  27  ACTIVITAT_EXERCICI_CONSULTA    68 non-null     object
#  28  FUMADOR_ACTIU                  104 non-null    object
#  29  CIGARRETES_DIA                 0 non-null      float64
#  30  COLESTEROL_TOTAL               0 non-null      float64
#  31  CONSELL_CONSUM_ALCOHOL         6 non-null      object
#  32  CRIBRATGE_AUDIT_C              52 non-null     object
#  33  CRIBRATGE_ALIMENTACIÓ          16 non-null     object
#  34  ESTAT_ACTIVITAT_FISICA         55 non-null     object
#  35  IMC                            106 non-null    object
#  36  MOTIVACIÓ_TABAC                1 non-null      object
#  37  PAQUETS_ANY_CONSUMITS          1 non-null      object
#  38  PES                            109 non-null    object
#  39  PAD                            119 non-null    object
#  40  PAS                            119 non-null    object
#  41  CBPAAT                         57 non-null     object
#  42  FREQ_CARDIACA                  119 non-null    object
#  43  SEDESTACIÓ_INTERROMPUDA        55 non-null     object
#  44  TEMPS_SEDESTACIO_H_D           46 non-null     object
#  45  TEST_FAGERSTRÖM_BREU           0 non-null      float64
#  46  EXPOSICIÓ_AMBIENTAL_TABAC      0 non-null      float64
#  47  INTERVENCIÓ_TABAC              93 non-null     object
#  48  Tipus de tabac                 0 non-null      float64
#  49  VALORACIÓ_AUDIT_C              19 non-null     object
#  50  VOLDRIA_DEIXAR_FUMAR           0 non-null      float64
#  51  HCM                            114 non-null    float64
#  52  RDW_CV                         67 non-null     float64
#  53  VPM                            9 non-null      float64
#  54  BASOFILS_PCT                   114 non-null    float64
#  55  CHCM                           114 non-null    float64
#  56  EOSINOFILS_PCT                 98 non-null     float64
#  57  HEMATIES                       114 non-null    float64
#  58  VCM                            114 non-null    float64
#  59  HEMATOCRIT                     115 non-null    float64
#  60  LEUCOCITS                      114 non-null    float64
#  61  LIMFOCITS_PCT                  114 non-null    float64
#  62  MONOCITS_PCT                   114 non-null    float64
#  63  NEUTROFILS_PCT                 113 non-null    float64
#  64  PDW                            0 non-null      float64
#  65  PLAQUETES                      114 non-null    float64
#  66  DIAGNÒSTIC_ASSOCIAT            133 non-null    object
# dtypes: float64(47), object(20)
# memory usage: 69.7+ KB

# %%
def clean_feature_names(df):
    """
    Normaliza los nombres de las columnas, elimina acentos/caracteres especiales
    y los reemplaza con su equivalente sin acento.
    """
    df = df.copy()
    
    # 1. Normalización de caracteres (quita acentos)
    def normalize_name(name):
        # Descomponer el carácter acentuado en su base + acento (ej. 'ò' -> 'o' + '`')
        nfkd_form = unicodedata.normalize('NFKD', str(name))
        # Eliminar todos los caracteres que no sean ASCII (se lleva los acentos)
        only_ascii = nfkd_form.encode('ascii', 'ignore').decode('utf-8')
        return only_ascii

    df.columns = [normalize_name(col) for col in df.columns]

    # 2. Limpieza de caracteres problemáticos restantes (guiones, paréntesis, etc.)
    # Se reemplazan los caracteres no alfanuméricos ni guiones bajos por un guion bajo
    df.columns = [re.sub(r'[^A-Za-z0-9_]', '_', str(col)) for col in df.columns]
    
    return df

df_investig_INR = clean_feature_names(df_investig_INR)

# %% [markdown]
# ## 2.3 Limpieza de datos

# %% [markdown]
# Los modelos de aprendizaje automático tienden a mejorar su precisión cuando se entrenan con grandes volúmenes de datos; no obstante, el tamaño de este conjunto podría no ser suficiente para alcanzar un rendimiento óptimo, por lo que evaluaremos si este es el caso.
#
# En las siguientes secciones nos enfocaremos en limpiar y preparar los datos para garantizar que el modelo trabaje con la información más confiable posible. Esto implica corregir errores de etiquetado o tipográficos, manejar valores faltantes y ajustar los tipos de datos según sea necesario.
#
# Además, muchos modelos requieren que los datos estén correctamente escalados y no contengan valores nulos para poder converger de manera efectiva. Dado que nuestro objetivo es que el modelo identifique patrones que no son evidentes a simple vista, aprovecharemos la información que sí podemos depurar para facilitar su aprendizaje y optimizar el proceso de entrenamiento.

# %% [markdown]
# ### 2.3.1 Valores faltantes y data types

# %%
info_complete = pd.DataFrame({
    'Dtype': df_investig_INR.dtypes,
    'Non-Null Count': df_investig_INR.notnull().sum()
})

# Mostrar todo
pd.set_option('display.max_rows', None)  # permite mostrar todas las filas
print(info_complete)
# Out:
#                                  Dtype  Non-Null Count
# CODI_PACIENT                    object             133
# INR                            float64             133
# ALT_GPT                        float64             103
# MICROALBUMINURIA               float64              70
# AST_GOT                        float64              70
# BILIRUBINA_TOTAL               float64              68
# CALCI                          float64              66
# CLORUR                         float64              22
# CREATINA_KINASA_CK             float64              16
# CREATININA                     float64             117
# FERRITINA                      float64              70
# FG_CKD_EPI                     float64              93
# FOSFATASA_ALCALINA             float64              66
# FERRO                          float64              50
# GLUCOSA                        float64             117
# HB_GLICOSILADA_A1C             float64              24
# HEMOGLOBINA                    float64             116
# POTASSI                        float64             113
# SODI                           float64             113
# LDH                            float64               8
# MAGNESI                        float64              16
# NT_PROBNP                      float64              34
# PCR                            float64              70
# PROTEINES_TOTALS               float64              53
# DIMER_D                        float64               0
# TROPONINA_I_ALTA_SENSIBILITAT  float64               2
# UREA                           float64              77
# ACTIVITAT_EXERCICI_CONSULTA     object              68
# FUMADOR_ACTIU                   object             104
# CIGARRETES_DIA                 float64               0
# COLESTEROL_TOTAL               float64               0
# CONSELL_CONSUM_ALCOHOL          object               6
# CRIBRATGE_AUDIT_C               object              52
# CRIBRATGE_ALIMENTACIO           object              16
# ESTAT_ACTIVITAT_FISICA          object              55
# IMC                             object             106
# MOTIVACIO_TABAC                 object               1
# PAQUETS_ANY_CONSUMITS           object               1
# PES                             object             109
# PAD                             object             119
# PAS                             object             119
# CBPAAT                          object              57
# FREQ_CARDIACA                   object             119
# SEDESTACIO_INTERROMPUDA         object              55
# TEMPS_SEDESTACIO_H_D            object              46
# TEST_FAGERSTROM_BREU           float64               0
# EXPOSICIO_AMBIENTAL_TABAC      float64               0
# INTERVENCIO_TABAC               object              93
# Tipus_de_tabac                 float64               0
# VALORACIO_AUDIT_C               object              19
# VOLDRIA_DEIXAR_FUMAR           float64               0
# HCM                            float64             114
# RDW_CV                         float64              67
# VPM                            float64               9
# BASOFILS_PCT                   float64             114
# CHCM                           float64             114
# EOSINOFILS_PCT                 float64              98
# HEMATIES                       float64             114
# VCM                            float64             114
# HEMATOCRIT                     float64             115
# LEUCOCITS                      float64             114
# LIMFOCITS_PCT                  float64             114
# MONOCITS_PCT                   float64             114
# NEUTROFILS_PCT                 float64             113
# PDW                            float64               0
# PLAQUETES                      float64             114
# DIAGNOSTIC_ASSOCIAT             object             133

# %% [markdown]
# El conjunto de datos muestra una disponibilidad muy desigual de información clínica. Mientras algunas variables básicas, como glucosa, creatinina, urea, sodio, potasio y ciertos parámetros de hemograma, presentan un número moderado de registros, la mayoría de las pruebas especializadas o duplicadas semánticamente están casi vacías.
#
# Esto refleja la **dinámica típica de un entorno clínico real**, donde solo algunos pacientes reciben mediciones específicas, generando un fuerte sesgo. En consecuencia, el dataset permite análisis generales sobre variables básicas, pero limita estudios más complejos que requieran biomarcadores avanzados o integrales.

# %% [markdown]
# En cuanto a los tipos de datos, observamos que muchos campos objeto, están siendo interpretados incorrectamente como variables categóricas. En realidad, solo los campos CODI_PACIENT y DIAGNÒSTIC ASSOCIATcontienen información categórica relevante que explica comportamientos o condiciones del paciente. Por ello, procederemos a transformar los datos, asegurando que cada variable tenga el tipo adecuado para el análisis y el entrenamiento de los modelos, lo que permitirá un procesamiento más preciso y coherente.

# %%
df_investig_INR = df_investig_INR.apply(lambda x: x.astype(str).str.strip())  # quitar espacios y convertir todo a string

exclude_cols = ["CODI_PACIENT", "DIAGNOSTIC_ASSOCIAT"]

cols_to_convert = [col for col in df_investig_INR.columns if col not in exclude_cols]

df_investig_INR[cols_to_convert] = df_investig_INR[cols_to_convert].apply(pd.to_numeric, errors="coerce").astype("float64")

df_investig_INR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 67 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   CODI_PACIENT                   133 non-null    object
#  1   INR                            133 non-null    float64
#  2   ALT_GPT                        103 non-null    float64
#  3   MICROALBUMINURIA               70 non-null     float64
#  4   AST_GOT                        70 non-null     float64
#  5   BILIRUBINA_TOTAL               68 non-null     float64
#  6   CALCI                          66 non-null     float64
#  7   CLORUR                         22 non-null     float64
#  8   CREATINA_KINASA_CK             16 non-null     float64
#  9   CREATININA                     117 non-null    float64
#  10  FERRITINA                      70 non-null     float64
#  11  FG_CKD_EPI                     93 non-null     float64
#  12  FOSFATASA_ALCALINA             66 non-null     float64
#  13  FERRO                          50 non-null     float64
#  14  GLUCOSA                        117 non-null    float64
#  15  HB_GLICOSILADA_A1C             24 non-null     float64
#  16  HEMOGLOBINA                    116 non-null    float64
#  17  POTASSI                        113 non-null    float64
#  18  SODI                           113 non-null    float64
#  19  LDH                            8 non-null      float64
#  20  MAGNESI                        16 non-null     float64
#  21  NT_PROBNP                      34 non-null     float64
#  22  PCR                            70 non-null     float64
#  23  PROTEINES_TOTALS               53 non-null     float64
#  24  DIMER_D                        0 non-null      float64
#  25  TROPONINA_I_ALTA_SENSIBILITAT  2 non-null      float64
#  26  UREA                           77 non-null     float64
#  27  ACTIVITAT_EXERCICI_CONSULTA    68 non-null     float64
#  28  FUMADOR_ACTIU                  104 non-null    float64
#  29  CIGARRETES_DIA                 0 non-null      float64
#  30  COLESTEROL_TOTAL               0 non-null      float64
#  31  CONSELL_CONSUM_ALCOHOL         6 non-null      float64
#  32  CRIBRATGE_AUDIT_C              52 non-null     float64
#  33  CRIBRATGE_ALIMENTACIO          16 non-null     float64
#  34  ESTAT_ACTIVITAT_FISICA         55 non-null     float64
#  35  IMC                            106 non-null    float64
#  36  MOTIVACIO_TABAC                1 non-null      float64
#  37  PAQUETS_ANY_CONSUMITS          1 non-null      float64
#  38  PES                            109 non-null    float64
#  39  PAD                            119 non-null    float64
#  40  PAS                            119 non-null    float64
#  41  CBPAAT                         57 non-null     float64
#  42  FREQ_CARDIACA                  119 non-null    float64
#  43  SEDESTACIO_INTERROMPUDA        55 non-null     float64
#  44  TEMPS_SEDESTACIO_H_D           46 non-null     float64
#  45  TEST_FAGERSTROM_BREU           0 non-null      float64
#  46  EXPOSICIO_AMBIENTAL_TABAC      0 non-null      float64
#  47  INTERVENCIO_TABAC              93 non-null     float64
#  48  Tipus_de_tabac                 0 non-null      float64
#  49  VALORACIO_AUDIT_C              19 non-null     float64
#  50  VOLDRIA_DEIXAR_FUMAR           0 non-null      float64
#  51  HCM                            114 non-null    float64
#  52  RDW_CV                         67 non-null     float64
#  53  VPM                            9 non-null      float64
#  54  BASOFILS_PCT                   114 non-null    float64
#  55  CHCM                           114 non-null    float64
#  56  EOSINOFILS_PCT                 98 non-null     float64
#  57  HEMATIES                       114 non-null    float64
#  58  VCM                            114 non-null    float64
#  59  HEMATOCRIT                     115 non-null    float64
#  60  LEUCOCITS                      114 non-null    float64
#  61  LIMFOCITS_PCT                  114 non-null    float64
#  62  MONOCITS_PCT                   114 non-null    float64
#  63  NEUTROFILS_PCT                 113 non-null    float64
#  64  PDW                            0 non-null      float64
#  65  PLAQUETES                      114 non-null    float64
#  66  DIAGNOSTIC_ASSOCIAT            133 non-null    object
# dtypes: float64(65), object(2)
# memory usage: 69.7+ KB

# %% [markdown]
# No es necesario realizar asociaciones adicionales entre variables para los contextos sociales del paciente, ya que factores como el consumo de alcohol y el tabaquismo ya están registrados como valores numéricos.

# %% [markdown]
# ### 2.3.2 Duplicados

# %%
df_investig_INR.duplicated(subset=['CODI_PACIENT']).sum()
# Out:
# 0

# %% [markdown]
# El método duplicated() devuelve False para las filas que no están duplicadas. Luego, al usar sum() sobre los resultados, solo se contabilizan los valores True. Podemos concluir que **no existen filas duplicadas en el dataset**. Eliminamos los registros duplicados.

# %% [markdown]
# ### 2.3.3 Eliminación de variables redundantes o irrelevantes

# %% [markdown]
# Para simplificar nuestro análisis y centrarnos en las variables más relevantes para la predicción del INR, eliminamos aquellas columnas que aportan información irrelevante o redundante. Esto incluye mediciones físicas generales, marcadores de laboratorio no relacionados directamente con la coagulación, y algunas columnas duplicadas o categóricas que no utilizaremos en esta etapa. Con esto, reducimos el ruido en los datos y facilitamos que el modelo aprenda patrones significativos de manera más eficiente.

# %%
cols_to_drop = ["ACTIVITAT_EXERCICI_CONSULTA","CIGARRETES_DIA","VOLDRIA_DEIXAR_FUMAR","EXPOSICIO_AMBIENTAL_TABAC","TEMPS_SEDESTACIO_H_D","SEDESTACIO_INTERROMPUDA","Tipus_de_tabac","ESTAT_ACTIVITAT_FISICA","CONSELL_CONSUM_ALCOHOL","ACTIVITAT_EXERCICI_CONSULTA","CRIBRATGE_AUDIT_C","CIGARRETES_DIA","PAQUETS_ANY_CONSUMITS","INTERVENCIO_TABAC","TEST_FAGERSTROM_BREU"]
df_investig_INR.drop(cols_to_drop, axis=1, inplace=True)

# %% [markdown]
# ### 2.3.4 Rangos y estadística básica

# %%
df_investig_INR.describe(include = np.number).round(2)
# Out:
#           INR  ALT_GPT  MICROALBUMINURIA  AST_GOT  BILIRUBINA_TOTAL  CALCI  \
# count  133.00   103.00             70.00    70.00             68.00  66.00
# mean     2.50    25.98             71.25    37.40              2.99   7.52
# std      0.37    32.05            181.47    50.29              6.20   2.78
# min      1.13     2.00              0.50    14.50              0.15   2.13
# 25%      2.34    13.20              4.73    20.62              0.47   6.37
# 50%      2.48    19.20             10.94    25.10              0.74   8.88
# 75%      2.69    27.15             44.11    34.20              2.00   9.29
# max      4.30   256.75           1149.60   303.00             41.00  10.56
#
#        CLORUR  CREATINA_KINASA_CK  CREATININA  FERRITINA  ...  EOSINOFILS_PCT  \
# count   22.00               16.00      117.00      70.00  ...           98.00
# mean   106.72               63.10       18.70     163.37  ...            2.93
# std      5.36               59.39       31.09     192.63  ...            1.95
# min     98.96               18.38        0.54       9.10  ...            0.00
# 25%    104.00               23.78        0.88      40.31  ...            1.62
# 50%    106.37               43.96        1.17     104.75  ...            2.50
# 75%    108.40               70.75       20.13     210.62  ...            3.80
# max    122.94              249.93      136.40    1243.49  ...           10.90
#
#        HEMATIES     VCM  HEMATOCRIT  LEUCOCITS  LIMFOCITS_PCT  MONOCITS_PCT  \
# count    114.00  114.00      115.00     114.00         114.00        114.00
# mean       4.25   90.57       39.42       6.83          25.62          9.14
# std        0.65   10.81        4.76       2.24          12.04          1.78
# min        2.47   13.40       27.70       2.53           2.75          4.80
# 25%        3.75   87.00       36.30       5.26          15.60          8.00
# 50%        4.30   91.98       39.85       6.16          24.82          9.40
# 75%        4.66   95.65       42.44       7.94          34.17          9.80
# max        6.30  123.10       52.30      16.17          53.10         13.80
#
#        NEUTROFILS_PCT  PDW  PLAQUETES
# count          113.00  0.0     114.00
# mean            62.41  NaN     216.62
# std             13.53  NaN      73.53
# min             33.45  NaN      97.00
# 25%             54.20  NaN     174.02
# 50%             61.80  NaN     203.50
# 75%             73.20  NaN     252.50
# max             92.40  NaN     547.00
#
# [8 rows x 52 columns]

# %%
# Check the stats of categorical features
df_investig_INR.describe(include='object')
# Out:
#        CODI_PACIENT DIAGNOSTIC_ASSOCIAT
# count           133                 133
# unique          133                  20
# top          ID0009               FA_NE
# freq              1                  67

# %% [markdown]
# El analisis presenta un patrón de datos disperso. La mayoría de las métricas están incompletas o ausentes, lo que sugiere que el conjunto de datos está diseñado para capturar un gran número de posibles características, pero la mayoría de las observaciones solo activan unas pocas.
#
# Donde hay suficientes datos, podemos ver que:
# - Hay métricas increíblemente robustas y estables (aquellas con medias superiores a 33 y de baja std), lo que implica que, cuando se activan, su valor es casi siempre el mismo.
# - Existen métricas altamente volátiles donde la media se ve afectada por valores atípicos masivos. Esto podría indicar que en la mayoría de los casos el valor es bajo o moderado, pero ocasionalmente se registra un evento o medición de magnitud excepcional.
#
# En resumen, el dataset no es un conjunto homogéneo de datos, sino una colección de mediciones donde la mayoría de las variables son binarias (medida o no medida) y, cuando se miden, pueden ser extremadamente consistentes o extremadamente variables, a menudo dominadas por outliers.

# %% [markdown]
# Para la trata de variables con insuficientes datos se procederá a la **eliminación de columnas** teniendo en cuenta:
#
# 1. Cobertura muy baja: columnas con muy pocos registros (<5% de los pacientes)
# 2. Pruebas especializadas: Hay biomarcadores o pruebas que solo se realizaron en subgrupos y no aportan información general.
#
# Ejemplos de columnas a eliminar: ALT (GPT), Creatinina, Glucosa

# %%
desc = df_investig_INR.describe(include=np.number).round(2)

# Seleccionar columnas cuyo count es menor o igual a 10
cols_a_quitar = desc.columns[desc.loc['count'] <= 10]

print(cols_a_quitar)

# Filtrar el DataFrame eliminando esas columnas
df_investig_INR = df_investig_INR.drop(columns=cols_a_quitar)

df_investig_INR.describe(include=np.number).round(2)
# Out:
# Index(['LDH', 'DIMER_D', 'TROPONINA_I_ALTA_SENSIBILITAT', 'COLESTEROL_TOTAL',
#        'MOTIVACIO_TABAC', 'VPM', 'PDW'],
#       dtype='object')
#           INR  ALT_GPT  MICROALBUMINURIA  AST_GOT  BILIRUBINA_TOTAL  CALCI  \
# count  133.00   103.00             70.00    70.00             68.00  66.00
# mean     2.50    25.98             71.25    37.40              2.99   7.52
# std      0.37    32.05            181.47    50.29              6.20   2.78
# min      1.13     2.00              0.50    14.50              0.15   2.13
# 25%      2.34    13.20              4.73    20.62              0.47   6.37
# 50%      2.48    19.20             10.94    25.10              0.74   8.88
# 75%      2.69    27.15             44.11    34.20              2.00   9.29
# max      4.30   256.75           1149.60   303.00             41.00  10.56
#
#        CLORUR  CREATINA_KINASA_CK  CREATININA  FERRITINA  ...    CHCM  \
# count   22.00               16.00      117.00      70.00  ...  114.00
# mean   106.72               63.10       18.70     163.37  ...   33.31
# std      5.36               59.39       31.09     192.63  ...    0.90
# min     98.96               18.38        0.54       9.10  ...   29.60
# 25%    104.00               23.78        0.88      40.31  ...   32.90
# 50%    106.37               43.96        1.17     104.75  ...   33.24
# 75%    108.40               70.75       20.13     210.62  ...   33.90
# max    122.94              249.93      136.40    1243.49  ...   35.50
#
#        EOSINOFILS_PCT  HEMATIES     VCM  HEMATOCRIT  LEUCOCITS  LIMFOCITS_PCT  \
# count           98.00    114.00  114.00      115.00     114.00         114.00
# mean             2.93      4.25   90.57       39.42       6.83          25.62
# std              1.95      0.65   10.81        4.76       2.24          12.04
# min              0.00      2.47   13.40       27.70       2.53           2.75
# 25%              1.62      3.75   87.00       36.30       5.26          15.60
# 50%              2.50      4.30   91.98       39.85       6.16          24.82
# 75%              3.80      4.66   95.65       42.44       7.94          34.17
# max             10.90      6.30  123.10       52.30      16.17          53.10
#
#        MONOCITS_PCT  NEUTROFILS_PCT  PLAQUETES
# count        114.00          113.00     114.00
# mean           9.14           62.41     216.62
# std            1.78           13.53      73.53
# min            4.80           33.45      97.00
# 25%            8.00           54.20     174.02
# 50%            9.40           61.80     203.50
# 75%            9.80           73.20     252.50
# max           13.80           92.40     547.00
#
# [8 rows x 45 columns]

# %% [markdown]
# Por otro lado, la **imputación de valores faltantes** solo tiene sentido en columnas que sean relativamente completas y clínicamente relevantes. Los criterios para aplicar la imputación serian:
#
# 1. Cobertura moderada: al menos 40–70% de los registros disponibles.
# 2. Relevancia clínica: variables importantes para análisis y el modelo predictivo.
#
# Ejemplos de columnas a aplicar la imputación: ALANINA AMINOTRANSFERASA (GPT/ALT), SUERO; POTASIO ION, SUERO
#
# Las variables continuas se imputaran con la mediana y las variables categoricas con la moda.

# %%
numerical = df_investig_INR.select_dtypes(include=['int64','float64']).columns.tolist()

for col in numerical:
    if df_investig_INR[col].isnull().any():
        mean_value = round(df_investig_INR[col].mean(), 2)
        df_investig_INR[col] = df_investig_INR[col].fillna(mean_value)

df_investig_INR.describe(include=np.number).round(2)
# Out:
#           INR  ALT_GPT  MICROALBUMINURIA  AST_GOT  BILIRUBINA_TOTAL   CALCI  \
# count  133.00   133.00            133.00   133.00            133.00  133.00
# mean     2.50    25.98             71.25    37.40              2.99    7.52
# std      0.37    28.17            131.21    36.36              4.42    1.95
# min      1.13     2.00              0.50    14.50              0.15    2.13
# 25%      2.34    14.60             10.30    25.00              0.71    7.52
# 50%      2.48    24.00             71.25    37.40              2.99    7.52
# 75%      2.69    25.98             71.25    37.40              2.99    8.88
# max      4.30   256.75           1149.60   303.00             41.00   10.56
#
#        CLORUR  CREATINA_KINASA_CK  CREATININA  FERRITINA  ...    CHCM  \
# count  133.00              133.00      133.00     133.00  ...  133.00
# mean   106.72               63.10       18.70     163.37  ...   33.31
# std      2.14               20.02       29.14     139.27  ...    0.84
# min     98.96               18.38        0.54       9.10  ...   29.60
# 25%    106.72               63.10        0.89      91.50  ...   32.95
# 50%    106.72               63.10        1.40     163.37  ...   33.31
# 75%    106.72               63.10       18.70     163.37  ...   33.80
# max    122.94              249.93      136.40    1243.49  ...   35.50
#
#        EOSINOFILS_PCT  HEMATIES     VCM  HEMATOCRIT  LEUCOCITS  LIMFOCITS_PCT  \
# count          133.00    133.00  133.00      133.00     133.00         133.00
# mean             2.93      4.25   90.57       39.42       6.83          25.62
# std              1.67      0.60   10.00        4.43       2.07          11.14
# min              0.00      2.47   13.40       27.70       2.53           2.75
# 25%              2.00      3.82   87.85       36.90       5.36          17.20
# 50%              2.93      4.25   90.65       39.42       6.77          25.62
# 75%              3.10      4.58   95.00       42.00       7.40          32.40
# max             10.90      6.30  123.10       52.30      16.17          53.10
#
#        MONOCITS_PCT  NEUTROFILS_PCT  PLAQUETES
# count        133.00          133.00     133.00
# mean           9.14           62.41     216.62
# std            1.64           12.47      68.04
# min            4.80           33.45      97.00
# 25%            8.20           55.10     180.33
# 50%            9.14           62.41     215.00
# 75%            9.80           72.50     241.00
# max           13.80           92.40     547.00
#
# [8 rows x 45 columns]

# %% [markdown]
# ### 2.3.5 Valores únicos
#
# El método `describe()` utilizado previamente muestra los valores únicos para las variables categóricas, ahora comprobamos los valores únicos de las características numéricas

# %%
for column in numerical:
  print(f"{column} has {df_investig_INR[column].nunique()} unique values.")
# Out:
# INR has 75 unique values.
# ALT_GPT has 73 unique values.
# MICROALBUMINURIA has 69 unique values.
# AST_GOT has 56 unique values.
# BILIRUBINA_TOTAL has 58 unique values.
# CALCI has 53 unique values.
# CLORUR has 19 unique values.
# CREATINA_KINASA_CK has 17 unique values.
# CREATININA has 92 unique values.
# FERRITINA has 69 unique values.
# FG_CKD_EPI has 67 unique values.
# FOSFATASA_ALCALINA has 61 unique values.
# FERRO has 49 unique values.
# GLUCOSA has 117 unique values.
# HB_GLICOSILADA_A1C has 21 unique values.
# HEMOGLOBINA has 93 unique values.
# POTASSI has 79 unique values.
# SODI has 78 unique values.
# MAGNESI has 17 unique values.
# NT_PROBNP has 35 unique values.
# PCR has 61 unique values.
# PROTEINES_TOTALS has 48 unique values.
# UREA has 77 unique values.
# FUMADOR_ACTIU has 4 unique values.
# CRIBRATGE_ALIMENTACIO has 3 unique values.
# IMC has 106 unique values.
# PES has 102 unique values.
# PAD has 100 unique values.
# PAS has 112 unique values.
# CBPAAT has 11 unique values.
# FREQ_CARDIACA has 102 unique values.
# VALORACIO_AUDIT_C has 3 unique values.
# HCM has 91 unique values.
# RDW_CV has 58 unique values.
# BASOFILS_PCT has 42 unique values.
# CHCM has 70 unique values.
# EOSINOFILS_PCT has 70 unique values.
# HEMATIES has 87 unique values.
# VCM has 105 unique values.
# HEMATOCRIT has 108 unique values.
# LEUCOCITS has 105 unique values.
# LIMFOCITS_PCT has 106 unique values.
# MONOCITS_PCT has 73 unique values.
# NEUTROFILS_PCT has 110 unique values.
# PLAQUETES has 101 unique values.

# %% [markdown]
# Los resultados que obtenermos son coherentes, no se necesita limpiar más los datos.

# %% [markdown]
# ## 2.4 Feature importance y analisis de la variable 'target'

# %% [markdown]
# #### 2.4.1 Análisis de dependencia y asociación

# %% [markdown]
# Se realiza un análisis de dependencia y asociación entre las variables del dataset y la variable objetivo, INR. El objetivo de este paso es identificar cuáles características tienen un efecto relevante sobre INR y cuáles podrían aportar información útil para la predicción, antes de pasar a modelos más complejos.
#
# Para ello, se empieza con **ANOVA (Análisis de Varianza)** el análisis de varianza indica si una variable independiente influye de manera importante en la media de la variable dependiente INR , al comparar el INR promedio entre los distintos niveles (grupos) de esa variable independiente. Es especialmente útil para detectar relaciones lineales o aditivas y ayuda a priorizar variables que muestran un efecto claro sobre la variable objetivo, sentando las bases para análisis posteriores más sofisticados como la información mutua o la correlación.

# %%
target_col = 'INR'

# Crear la columna categórica INR_Group
bins = [df_investig_INR[target_col].min() - 1, 2.0, 3.0 + 1e-6, df_investig_INR[target_col].max() + 1]
df_investig_INR['INR_Group'] = pd.cut(
    df_investig_INR[target_col], 
    bins=bins, 
    labels=['Bajo (<2.0)', 'Normal (2.0-3.0)', 'Alto (>3.0)'], 
    right=False, 
    include_lowest=True
).astype('category')

# %%
# Inicializar diccionarios
anova_results = {}
constant_columns = []

# Umbral de significancia
alpha = 0.05

# Iterar por columnas numéricas excepto INR e INR_Group
numeric_cols = df_investig_INR.select_dtypes(include='number').columns.difference(["INR"])
for col in numeric_cols:
    groups = [
        df_investig_INR[col][df_investig_INR["INR_Group"] == g]
        for g in df_investig_INR["INR_Group"].cat.categories
    ]
    
    # Verificar que cada grupo tenga más de un valor único
    if all(len(g.unique()) > 1 for g in groups):
        f_stat, p_val = stats.f_oneway(*groups)
        anova_results[col] = {"F": f_stat, "p_value": p_val, "Significant": p_val < alpha}
    else:
        constant_columns.append(col)

# Mostrar columnas con algún grupo constante
if constant_columns:
    print("Columnas con algún grupo constante:", constant_columns)
else:
    print("No hay columnas con grupos constantes")

# Convertir resultados a DataFrame
anova_df = pd.DataFrame(anova_results).T
anova_df = anova_df.sort_values("F", ascending=False)
anova_plot_df = anova_df.reset_index()
anova_plot_df["Significant"] = anova_plot_df["Significant"].astype(str)  # True/False como string

plt.figure(figsize=(12, 6))
sns.barplot(
    data=anova_plot_df,
    x="index",
    y="F",
    hue="Significant",
    dodge=False,        # barras no separadas
    palette={"True": "red", "False": "blue"},
    legend=False
)
plt.axhline(y=0, color='black', linewidth=0.8)
plt.xticks(rotation=45, ha='right')
plt.ylabel("Estadístico F")
plt.xlabel("Variables")
plt.title("Resultados ANOVA por variable (rojo = significativo)")
plt.tight_layout()
plt.show()
# Out:
# Columnas con algún grupo constante: ['CBPAAT', 'CREATINA_KINASA_CK', 'CRIBRATGE_ALIMENTACIO', 'MAGNESI', 'VALORACIO_AUDIT_C']

# %% [markdown]
# Tukey HSD (Post Hoc) que realizaste. Se utiliza para identificar exactamente qué pares de grupos son significativamente diferente.

# %%
alpha = 0.05
significant_vars = anova_df[anova_df['p_value'] < alpha].index.tolist()

# Configuración de columnas y filas
n_cols = 3  # número de columnas (ajusta según preferencia)
n_vars = len(significant_vars)
n_rows = math.ceil(n_vars / n_cols)

# Tamaño total de la figura
fig_width = 17 * n_cols   # 5 pulgadas por columna
fig_height = 7 * n_rows  # 5 pulgadas por fila
fig, axes = plt.subplots(n_rows, n_cols, figsize=(fig_width, fig_height))

# Aplanar axes para iterar fácilmente
axes = axes.flatten()

for ax, variable in zip(axes, significant_vars):
    tukey_results = pairwise_tukeyhsd(
        endog=df_investig_INR[variable],
        groups=df_investig_INR['INR_Group'],
        alpha=alpha
    )
    tukey_results.plot_simultaneous(ax=ax, xlabel=variable, ylabel="INR_Group")
    ax.set_title(f"Tukey HSD: {variable}", fontsize=10)

# Ocultar subplots sobrantes si hay menos variables que subplots
for ax in axes[n_vars:]:
    ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 2.4.2 Análisis de predicción y relevancia

# %% [markdown]
# A continuación, se procederá a realizar un análisis de predicción y relevancia con el objetivo de identificar qué variables aportan información significativa para explicar y predecir la variabilidad del INR. Para ello, se empleará **información mutua (MI)**, una medida que captura la dependencia entre variables sin asumir linealidad, lo que permite detectar relaciones complejas o no evidentes entre los factores clínicos y la variable objetivo.
#
# Se ha elegido un umbral de **MI de 0.15**, lo suficientemente bajo para no descartar variables con señal débil pero relevante, y al mismo tiempo alto para evitar incluir características que aporten información mínima o ruido. Aplicando este criterio, se identificaron como variables más relevantes: ALBÚMINA  (MAU) ORINA, CREATINA_KINASA_CK, MICROALBUMINURIA,CLORUR, VALORACIÓ_AUDIT_C, CRIBRATGE_ALIMENTACIÓ.

# %% [markdown]
# Para el análisis de información mutua, se creó una columna categórica a partir del INR en lugar de usarlo como continuo. Esto permite identificar más fácilmente qué variables están asociadas a cambios relevantes en los rangos de INR (“Bajo”, “Normal”, “Alto”) y evita que pequeñas variaciones numéricas generen ruido, haciendo los resultados más interpretables y útiles.

# %%
# Variable objetivo para MI
target_col = 'INR_Group'
threshold = 0.15
non_numeric_cols_to_keep = ["CODI_PACIENT", "DIAGNÒSTIC ASSOCIAT"]

# Identificar variables numéricas y categóricas
df_features = df_investig_INR.drop(columns=[target_col, 'CODI_PACIENT','INR'])

numeric_cols = df_features.select_dtypes(include=np.number).columns.tolist()
categorical_cols = df_features.select_dtypes(include=['object', 'category']).columns.tolist()

# Convertir categóricas a numericas
df_encoded = df_features.copy()
for col in categorical_cols:
    df_encoded[col] = df_encoded[col].astype('category').cat.codes

# Indicar qué columnas son discretas (todas las categóricas codificadas)
discrete_features = [col in categorical_cols for col in df_encoded.columns]

# Calcular MI
X = df_encoded
y = df_investig_INR[target_col]
mi_scores = mutual_info_classif(X, y, discrete_features=discrete_features, random_state=42)
mi_series = pd.Series(mi_scores, index=X.columns).sort_values(ascending=False)

# Filtrar variables que superan el umbral
selected_mi = mi_series[mi_series >= threshold]
print(selected_mi)

# Gráfico de Información Mutua
plt.figure(figsize=(14, 16))
sns.set_style("whitegrid")
plot_data = mi_series.reindex(mi_series.sort_values(ascending=False).index)
colors = ['darkred' if v >= threshold else 'lightgray' for v in plot_data.values]

plt.barh(plot_data.index, plot_data.values, color=colors)
plt.axvline(threshold, color='green', linestyle='--', linewidth=1.5, label=f'Umbral MI ({threshold})')
plt.title(f'Importancia de las Variables según Información Mutua con {target_col}', fontsize=16)
plt.xlabel('Información Mutua', fontsize=14)
plt.ylabel('Variable', fontsize=14)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# CREATINA_KINASA_CK       0.379373
# NT_PROBNP                0.378356
# VALORACIO_AUDIT_C        0.373809
# CBPAAT                   0.349384
# CLORUR                   0.348550
# MAGNESI                  0.293998
# CRIBRATGE_ALIMENTACIO    0.276531
# PES                      0.218047
# HB_GLICOSILADA_A1C       0.173012
# IMC                      0.171402
# DIAGNOSTIC_ASSOCIAT      0.150057
# dtype: float64

# %% [markdown]
# #### 2.4.3 Correlación

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Numeric columns without target
numeric_cols = [
    col for col in df_investig_INR.select_dtypes(include=np.number).columns
    if col not in ['INR']
]

target_col = 'INR'

# Pearson correlation matrix
corr_matrix = df_investig_INR[numeric_cols + [target_col]].corr(method='pearson')
#print(corr_matrix)
# Correlation of all variables with INR
corr_with_inr = corr_matrix[target_col].drop(target_col).abs().sort_values(ascending=False)


# Plot heatmap
plt.figure(figsize=(40, 16))  # Ampliamos el tamaño del gráfico
sns.set(font_scale=1.2)

sns.heatmap(
    corr_matrix,
    annot=True,
    fmt=".2f",  # Redondea los floats a 2 decimales
    linewidths=.5,
    cmap="Blues"
)

plt.title(f'Variables Most Correlated with INR', fontsize=18)
plt.show()

# %% [markdown]
# El análisis de esta densa matriz de correlación de Pearson nos permite tejer un relato sobre los factores que influyen en el INR (Razón Normalizada Internacional), aunque la historia que nos cuenta es de complejidad y sutilidad. Se hace evidente que ninguna variable clínica por sí sola ejerce una influencia dominante sobre el INR, ya que las correlaciones más altas apenas alcanzan el valor de $0.26$, sugiriendo que el INR es, en esencia, el resultado de una interacción compleja que abarca la medicación, la función hepática y el estilo de vida.Sin embargo, en este mar de asociaciones débiles, emergen dos correlaciones positivas destacadas, ambas en $0.26$: la Valoración AUDIT-C y la Frecuencia Cardíaca. La asociación con el AUDIT-C, que es un indicador del consumo de alcohol, parece señalar un mecanismo indirecto pero crítico: el consumo etílico puede dañar la función hepática, y un hígado comprometido sintetiza menos factores de coagulación, lo que consecuentemente eleva el INR. Por otro lado, la correlación con la Frecuencia Cardíaca probablemente actúa como un marcador indirecto, reflejando que los pacientes con frecuencias elevadas a menudo padecen arritmias cardíacas que requieren tratamiento anticoagulante para mantener el INR en un rango terapéutico.Descendiendo en la escala, otras variables como el Cloruro en Suero ($0.20$) y ciertos parámetros hematológicos como el VCM, la Hemoglobina y el Hematocrito (entre $0.14$ y $0.16$) mantienen asociaciones positivas aún más modestas, sugiriendo influencias secundarias o el simple reflejo de una condición sistémica subyacente que también afecta a la coagulación.En un plano diferente, al examinar las interrelaciones entre las demás variables, la matriz nos alerta sobre una fuerte redundancia. Parámetros como el VCM y la HCM, y de manera similar la Hemoglobina y el Hematocrito, se correlacionan casi perfectamente (con valores de $0.95$ y $0.89$ respectivamente), ilustrando una clara multicolinealidad. Esta redundancia interna nos indica que, si buscamos construir un modelo predictivo estable, deberemos seleccionar solo una variable de cada par altamente relacionado. Finalmente, en contraste con las asociaciones positivas, destaca una correlación negativa moderada entre el recuento de Hematíes y la HCM ($-0.49$), mostrando la relación inversa entre la cantidad de glóbulos rojos y el contenido de hemoglobina en cada uno.En resumen, los hallazgos sugieren que las influencias más significativas sobre el INR provienen de factores relacionados con el estado hepático (alcohol) y las indicaciones clínicas para la anticoagulación (frecuencia cardíaca), pero la predicción precisa del INR es un reto que exige la consideración conjunta de un espectro más amplio de variables para desentrañar su compleja etiología.

# %% [markdown]
# Tras completar los tres análisis —ANOVA para evaluar dependencia, Información Mutua para medir relevancia predictiva y Pearson para identificar relaciones lineales— se obtuvo una visión conjunta y más equilibrada de las variables que aportan información útil sobre el comportamiento del INR.
#
# Este conjunto reducido se utilizará para realizar un análisis de pair plots con el fin de detectar visualmente valores atípicos.

# %% [markdown]
# #### 2.4.5 Pair plots para detectar visualmente valoes atípicos y potenciales relaciones entre variables

# %%
columns_to_keep = ['INR_Group','FREQ_CARDIACA', 'HEMOGLOBINA', 'SODI', 'VALORACIO_AUDIT_C','CBPAAT', 'MICROALBUMINURIA', 'VCM','INR']
df_investig_INR_plot = df_investig_INR[columns_to_keep]

# 4. Obtener variables numéricas
plot_features = df_investig_INR_plot.select_dtypes(include=np.number).columns.tolist()

# Usar todas las variables en un solo plot
chunks = [plot_features]

# 6. Configuración visual
colors = ["#f39c12", "#2ecc71", "#e74c3c"]
hue_order = ['Bajo (<2.0)', 'Normal (2.0-3.0)', 'Alto (>3.0)']

sns.set(font_scale=0.7)

threshold_display = 0.10

for i, chunk in enumerate(chunks):
    plot_df = df_investig_INR_plot[chunk + ['INR_Group']]
    
    ax = sns.pairplot(
        plot_df,
        hue='INR_Group',
        palette=colors,
        hue_order=hue_order,
        height=1.2,
        aspect=1.0,
        kind="scatter",
        diag_kind="kde"
    )

    title = f'Pair Plot {i+1} de {len(chunks)}: Variables con |r| > {threshold_display}'
    ax.fig.suptitle(title, size=14, y=1.03)

    # ------------------------------------------------------------------
    # Guardar figura
    filename = f"pairplot_{i+1}_variables.png"
    ax.fig.savefig(filename, dpi=300, bbox_inches='tight')
    print(f"Guardado: {filename}")
    # ------------------------------------------------------------------

    plt.show()
# Out:
# Guardado: pairplot_1_variables.png

# %% [markdown]
# El pair plot revela que la mayoría de los pacientes tienen niveles de INR Normal (2.0-3.0), dominando la distribución de todas las variables clínicas. Las variables clínicas como HEMOGLOBINA y VCM muestran una ausencia de correlaciones lineales fuertes entre sí, indicando que son relativamente independientes en este grupo. Los grupos de INR Bajo y Alto (los extremos de riesgo) no se separan ni se agrupan de manera distintiva en los planos de las variables clínicas. Esto sugiere que una predicción simple del grupo de INR a partir de estas variables será difícil, ya que los valores de riesgo se mezclan con los valores del grupo Normal en la mayoría de las comparaciones bivariadas.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# --- Código Modificado ---

# Definir las variables que queremos visualizar
vars_to_plot = ['ALT_GPT', 'MICROALBUMINURIA', 'CREATININA', 'PCR']

# Creamos una figura con subplots para las primeras dos variables
# Usaremos 1 fila y 2 columnas para ALT_GPT y MICROALBUMINURIA
fig, axs = plt.subplots(1, 2, figsize=(14, 6))

### 📊 Diagrama de Cajas para ALT_GPT ###
sns.boxplot(y=df_investig_INR['ALT_GPT'], color="#4C72B0", ax=axs[0])
axs[0].set_title('ALT_GPT - Detección de Outliers (Método IQR)')
axs[0].set_ylabel('ALT_GPT (Unidades)')
axs[0].grid(axis='y', alpha=0.6)

### 🔬 Diagrama de Cajas para MICROALBUMINURIA (con escala logarítmica) ###
# Usamos una escala logarítmica para manejar el sesgo y visualizar mejor los outliers altos
sns.boxplot(y=df_investig_INR['MICROALBUMINURIA'], color="#55A868", ax=axs[1])
axs[1].set_yscale("log") # Aplicamos la escala logarítmica
axs[1].set_title('MICROALBUMINURIA - Outliers (Escala Logarítmica)')
axs[1].set_ylabel('MICROALBUMINURIA (log)')
axs[1].grid(axis='y', alpha=0.6)

plt.suptitle('Análisis de Outliers utilizando Boxplots (Método IQR) en Variables Clínicas Clave', fontsize=16, y=1.02)
plt.tight_layout(rect=[0, 0, 1, 0.98]) # Ajustamos layout para el título superior
plt.show()

# %% [markdown]
# ALT_GPT: La mayoría de los datos se concentran en valores muy bajos (la caja es pequeña y cercana a cero). Sin embargo, hay muchos outliers (puntos individuales) por encima de 50, con algunos valores extremos que superan las 200 y 250 unidades. Estos son clínicamente relevantes (posible daño hepático).
#
# MICROALBUMINURIA (Logarítmica): La distribución es fuertemente sesgada. La caja principal está muy cerca de la parte inferior del gráfico, pero la escala logarítmica revela claramente que hay numerosos outliers que se extienden en varios órdenes de magnitud. Estos valores atípicos altos son indicadores de enfermedad renal avanzada.

# %% [markdown]
# #### 2.4.6 Distribución de frecuencias

# %%
plt = display_categorical("INR_Group",df=df_investig_INR)
plt.show()

# %% [markdown]
# La distribución de la variable objetivo INR_Group revela una marcada asimetría.La gran mayoría de las observaciones pertenecen a la categoría Normal (2.0-3.0), con un recuento de 120. En contraste, las categorías de interés clínico, Bajo (<2.0) y Alto (>3.0), son minorías muy reducidas, contando con solo 7 y 6 observaciones, respectivamente. Esta fuerte desproporción de clases (un dataset altamente desbalanceado) es un factor crítico que debe ser considerado en cualquier análisis o modelado subsiguiente, ya que el modelo tenderá a sesgarse hacia la clase mayoritaria.

# %%
plt = display_numerical('VALORACIO_AUDIT_C', df=df_investig_INR)
plt.show()
# Out:
# c:\Users\VALER\OneDrive\Escritorio\anticoagulant-patology-analysis\utils\personalize_charts.py:92: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   display(df.groupby('INR_Group')[feature].describe())
#                   count      mean       std   min   25%   50%   75%   max
# INR_Group
# Bajo (<2.0)         7.0  0.210000  0.000000  0.21  0.21  0.21  0.21  0.21
# Normal (2.0-3.0)  120.0  0.203500  0.145773  0.00  0.21  0.21  0.21  1.00
# Alto (>3.0)         6.0  0.341667  0.322516  0.21  0.21  0.21  0.21  1.00

# %% [markdown]
# #### 2.4.6 Variables categoricas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Calcular los conteos de las combinaciones (cross-tabulation)
# Reemplaza 'DIAGNÒSTIC_ASSOCIAT' y 'INR_Group' con tus columnas reales si son diferentes.
data_counts = df_investig_INR.groupby(['DIAGNOSTIC_ASSOCIAT', 'INR_Group']).size().unstack(fill_value=0)

# 2. Configuración y creación del gráfico de barras apiladas
plt.figure(figsize=(40, 6))
sns.set(font_scale = 1.5) # Mantener el estilo de Seaborn

# Obtener los nombres de los diagnósticos
diagnostics = data_counts.index

# Inicializar una base para las barras apiladas (comienza en cero)
bottom = None

# Recorrer cada grupo de INR_Group para apilar
for i, group in enumerate(data_counts.columns):
    # Usar una paleta de colores de Matplotlib/Seaborn
    color = sns.color_palette('Set2', n_colors=len(data_counts.columns))[i]
    
    # Crear la barra para el grupo actual, apilándola sobre 'bottom'
    plt.bar(
        diagnostics, 
        data_counts[group], 
        bottom=bottom, 
        label=group, 
        color=color
    )
    
    # Actualizar la base para la siguiente barra apilada
    if bottom is None:
        bottom = data_counts[group]
    else:
        bottom = bottom + data_counts[group]

plt.title("Distribución de DIAGNÒSTIC ASSOCIAT según INR_Group (Apilado)")
plt.xlabel("Diagnóstico")
plt.ylabel("Conteo")
plt.legend(title="INR_Group")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\VALER\AppData\Local\Temp\ipykernel_6776\2897110745.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data_counts = df_investig_INR.groupby(['DIAGNOSTIC_ASSOCIAT', 'INR_Group']).size().unstack(fill_value=0)

# %% [markdown]
# El gráfico de barras presenta la distribución de los diferentes DIAGNÓSTICOS ASOCIADOS dentro de cada categoría de la variable objetivo, el INR_Group (Bajo, Normal, Alto).
#
# Una observación inmediata es el dominio absoluto del grupo INR Normal (2.0-3.0), representado por las barras de color naranja, en la inmensa mayoría de los diagnósticos. Esta preponderancia refleja el desbalance de clases previamente identificado en el conjunto de datos.
#
# El diagnóstico FA_NE (Fibrilación Auricular No Específica) es, con diferencia, el diagnóstico más frecuente en toda la cohorte, acumulando el mayor número de casos, casi todos ellos clasificados en el grupo INR Normal.

# %% [markdown]
# #### 2.3.3 Feature importance: conclusión
#
# El proceso de construcción del modelo requiere una selección estratégica de características, guiada por el análisis de correlación y la necesidad de gestionar la redundancia de datos.
#
# El análisis de la matriz de correlación ha establecido que la variabilidad del INR no está dominada por una única variable clínica, dado que las correlaciones más altas observadas, como las de VALORACIÓ_AUDIT_C y FREQ_CARDIACA (ambas con un coeficiente de 0.26), son bajas. Estas asociaciones débiles sugieren que el INR es una variable de resultado multicausal que integra factores como la exposición a alcohol (AUDIT-C, indicador de la función hepática) y la necesidad de anticoagulación (FREQ_CARDIACA, asociada a arritmias).
#
# Por otro lado, la matriz de interrelaciones internas subraya una fuerte multicolinealidad entre ciertos pares de parámetros sanguíneos: VCM y HCM (0.95), así como Hemoglobina y Hematocrito (0.89). Esta redundancia exige la selección de solo una variable por cada par para garantizar la estabilidad de los modelos durante el entrenamiento.
#
# Fases de Modelado y Gestión de Características
# Para abordar la tarea, se entrenarán diferentes arquitecturas de modelos con el objetivo de seleccionar el de mejor rendimiento. Durante esta fase, se evaluará rigurosamente el impacto de la inclusión o exclusión de variables mediante la verificación programática del rendimiento. Si la presencia o eliminación de una característica no afecta los resultados de un modelo específico, dicha característica se considera irrelevante para ese modelo y puede ser descartada para optimizar las fases posteriores de ajuste de parámetros, validación y prueba.
#
# Además de la selección basada en correlación y redundancia, otras técnicas de ingeniería de características podrían ser consideradas:
#
# Identificación de Colinealidades no Lineales: Se podría explorar la creación de características polinómicas o la aplicación de métodos de reducción de dimensionalidad como el Análisis de Componentes Principales (PCA) o el Análisis Discriminante Lineal (LDA) para simplificar el espacio de características.
#
# Gestión del Desbalance de Clases: El conjunto de datos presenta un severo desbalance de clases en la variable objetivo INR_Group, donde la clase Normal es mayoritaria y las clases Bajo y Alto son minorías. Técnicas como SMOTE (Synthetic Minority Over-sampling Technique) podrían ser consideradas para mitigar este desequilibrio.

# %%
variables_seleccionadas = ['CODI_PACIENT','INR','CALCI', 'HEMOGLOBINA', 'VCM', 'HEMATOCRIT','PLAQUETES','DIAGNOSTIC_ASSOCIAT','IMC','HB_GLICOSILADA_A1C','PES','CRIBRATGE_ALIMENTACIO','MAGNESI','CLORUR','CBPAAT','VALORACIO_AUDIT_C','NT_PROBNP','CREATINA_KINASA_CK','FREQ_CARDIACA','PCR','HEMATIES']

# Crear un nuevo DataFrame solo con esas columnas
df_investig_INR_all = df_investig_INR[variables_seleccionadas]
df_investig_INR_all.to_csv('data/df_investig_INR_all.csv')

# %%
variables_seleccionadas = ['INR','CALCI', 'HEMOGLOBINA', 'VCM', 'HEMATOCRIT','PLAQUETES','DIAGNOSTIC_ASSOCIAT','IMC','HB_GLICOSILADA_A1C','PES','CRIBRATGE_ALIMENTACIO','MAGNESI','CLORUR','CBPAAT','VALORACIO_AUDIT_C','NT_PROBNP','CREATINA_KINASA_CK','FREQ_CARDIACA','PCR','HEMATIES']

# Crear un nuevo DataFrame solo con esas columnas
df_investig_INR = df_investig_INR[variables_seleccionadas]

# %%
df_investig_INR.info()
df_investig_INR.to_csv('data/df_investig_INR.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   INR                    133 non-null    float64
#  1   CALCI                  133 non-null    float64
#  2   HEMOGLOBINA            133 non-null    float64
#  3   VCM                    133 non-null    float64
#  4   HEMATOCRIT             133 non-null    float64
#  5   PLAQUETES              133 non-null    float64
#  6   DIAGNOSTIC_ASSOCIAT    133 non-null    object
#  7   IMC                    133 non-null    float64
#  8   HB_GLICOSILADA_A1C     133 non-null    float64
#  9   PES                    133 non-null    float64
#  10  CRIBRATGE_ALIMENTACIO  133 non-null    float64
#  11  MAGNESI                133 non-null    float64
#  12  CLORUR                 133 non-null    float64
#  13  CBPAAT                 133 non-null    float64
#  14  VALORACIO_AUDIT_C      133 non-null    float64
#  15  NT_PROBNP              133 non-null    float64
#  16  CREATINA_KINASA_CK     133 non-null    float64
#  17  FREQ_CARDIACA          133 non-null    float64
#  18  PCR                    133 non-null    float64
#  19  HEMATIES               133 non-null    float64
# dtypes: float64(19), object(1)
# memory usage: 20.9+ KB
